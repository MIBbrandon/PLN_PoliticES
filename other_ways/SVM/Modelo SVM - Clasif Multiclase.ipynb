# %% [markdown]
# **Librerías**

# %%
import numpy as np
from google.colab import drive
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report
import matplotlib.pyplot as plt
import seaborn as sb
import pandas as pd
from sklearn.model_selection import train_test_split
import nltk
from nltk.corpus import stopwords
from nltk import word_tokenize
from nltk.stem.porter import PorterStemmer
import re
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.pipeline import Pipeline
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report

# %% [markdown]
# **Cargar el dataset**

# %%
drive.mount('/content/drive')
PATH = "/content/drive/My Drive/PLN/PRÁCTICA FINAL/"
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv(PATH+"politicES_phase_2_train_public.csv") 
print('dataset cargado:', df.shape)
df.head()
# Out:
# dataset cargado: (180000, 6)
#                               label  gender  profession ideology_binary  \
# 0  0008c4fab9e97623a60380ee9c88cb20  female  politician            left
# 1  0008c4fab9e97623a60380ee9c88cb20  female  politician            left
# 2  0008c4fab9e97623a60380ee9c88cb20  female  politician            left
# 3  0008c4fab9e97623a60380ee9c88cb20  female  politician            left
# 4  0008c4fab9e97623a60380ee9c88cb20  female  politician            left
#
#   ideology_multiclass                                              tweet
# 0                left  ¡Feliz 28 de febrero a todas las andaluzas y a...
# 1                left  Feliz año nuevo, feliz esperanza 💕. Querido 20...
# 2                left  🇩🇪🇪🇸 ¡Un placer encontrarme con mi homólogo al...
# 3                left  El conflicto en Ucrania ha supuesto una dramát...
# 4                left  La Academia de la Llingua Asturiana realiza un...

# %% [markdown]
# **Para la clasificación multiclase me quedo solamente con los campos "tweet" y "ideology_multiclass"**

# %%
df_cb=df[['tweet', 'ideology_multiclass']].rename(columns={'tweet': 'text', 'ideology_multiclass': 'label'})
df_cb.head()
# Out:
#                                                 text label
# 0  ¡Feliz 28 de febrero a todas las andaluzas y a...  left
# 1  Feliz año nuevo, feliz esperanza 💕. Querido 20...  left
# 2  🇩🇪🇪🇸 ¡Un placer encontrarme con mi homólogo al...  left
# 3  El conflicto en Ucrania ha supuesto una dramát...  left
# 4  La Academia de la Llingua Asturiana realiza un...  left

# %% [markdown]
# **Crear particiones**

# %%
# quitar las siguientes 4 líneas para coger todos los datos
parte_test = 0.6
df_train, df_aux = np.split(df_cb, [int((1 - parte_test) * len(df))])
X=df_train['text'] 
y=df_train['label']

#X=df_cb['text'] 
#y=df_cb['label']

X_train, X_aux, y_train, y_aux = train_test_split(X, y, 
        test_size=0.30, random_state=42, stratify=y)

X_val, X_test, y_val, y_test = train_test_split(X_aux, y_aux, 
        test_size=0.5, random_state=42, stratify=y_aux)

print('Tamaño conjunto de entrenamiento:', len(X_train))
print('Tamaño conjunto de validación:', len(X_val))
print('Tamaño conjunto de evaluación:', len(X_test))
# Out:
# Tamaño conjunto de entrenamiento: 50400
# Tamaño conjunto de validación: 10800
# Tamaño conjunto de evaluación: 10800

# %% [markdown]
# **Distribución de las clases**

# %%
counts_train = y_train.value_counts().to_dict()
print("Distribución en training:", counts_train)
counts_val = y_val.value_counts().to_dict()
print("Distribución en validación:", counts_val)
counts_test = y_test.value_counts().to_dict()
print("Distribución en test:", counts_test)

LABELS=counts_train.keys()
print(LABELS)
# Out:
# Distribución en training: {'moderate_left': 19432, 'moderate_right': 16184, 'left': 8960, 'right': 5824}
# Distribución en validación: {'moderate_left': 4164, 'moderate_right': 3468, 'left': 1920, 'right': 1248}
# Distribución en test: {'moderate_left': 4164, 'moderate_right': 3468, 'left': 1920, 'right': 1248}
# dict_keys(['moderate_left', 'moderate_right', 'left', 'right'])

# %%
fig, (ax_train, ax_val, ax_test) = plt.subplots(1, 3, figsize=(20, 4))
fig.suptitle('Distribución de clases')
ax_train.bar(LABELS, counts_train.values(), width=0.4)
ax_train.set_title('Distribución de clases en el conjunto de entrenamiento')
ax_train.set_xlabel('Clases')
ax_train.set_ylabel('Número de Instancias')

ax_val.bar(LABELS, counts_val.values(), width=0.4)
ax_val.set_title('Distribución de clases en el conjunto de validación')
ax_val.set_xlabel('Clases')
ax_val.set_ylabel('Número de Instancias')


ax_test.bar(LABELS, counts_test.values(), width=0.4)
ax_test.set_title('Distribución de clases en el conjunto de evaluación')
ax_test.set_xlabel('Clases')
ax_test.set_ylabel('Número de Instancias')
# Out:
# Text(0, 0.5, 'Número de Instancias')

# %% [markdown]
# **Distribución del tamaño de los textos**

# %%
length_train=X_train.apply(lambda text: len(text.split()))
length_train.describe()
# Out:
# count    50400.000000
# mean        28.806845
# std         12.715682
# min          4.000000
# 25%         17.000000
# 50%         28.000000
# 75%         40.000000
# max         62.000000
# Name: text, dtype: float64

# %%
length_train.describe(percentiles=[0.25, 0.50, 0.75, 0.90, 0.95, 0.99])
# Out:
# count    50400.000000
# mean        28.806845
# std         12.715682
# min          4.000000
# 25%         17.000000
# 50%         28.000000
# 75%         40.000000
# 90%         46.000000
# 95%         48.000000
# 99%         52.000000
# max         62.000000
# Name: text, dtype: float64

# %%
length_val=X_val.apply(lambda text: len(text.split()))
length_val.describe(percentiles=[0.25, 0.50, 0.75, 0.90, 0.95, 0.99])
# Out:
# count    10800.000000
# mean        28.714444
# std         12.877950
# min          6.000000
# 25%         17.000000
# 50%         28.000000
# 75%         41.000000
# 90%         46.000000
# 95%         48.000000
# 99%         53.000000
# max         60.000000
# Name: text, dtype: float64

# %%
length_test=X_test.apply(lambda text: len(text.split()))
length_test.describe(percentiles=[0.25, 0.50, 0.75, 0.90, 0.95, 0.99])
# Out:
# count    10800.000000
# mean        28.660278
# std         12.735757
# min          4.000000
# 25%         17.000000
# 50%         28.000000
# 75%         40.000000
# 90%         46.000000
# 95%         48.000000
# 99%         52.000000
# max         61.000000
# Name: text, dtype: float64

# %%
fig, (ax_train, ax_val, ax_test) = plt.subplots(1, 3, figsize=(20, 4))
fig.suptitle('Distribución del tamaño de los textos')

ax_train.hist(length_train,  color = 'red', edgecolor = 'black',
         bins = int(600/50))
ax_train.set_title('Conjunto de entrenamiento')
ax_train.set_xlabel('Tamaño')
ax_train.set_ylabel('Número de Instancias')

ax_val.hist(length_train,  color = 'red', edgecolor = 'black',
         bins = int(200/15))
ax_val.set_title('Conjunto de validación')
ax_val.set_xlabel('Tamaño')
ax_val.set_ylabel('Número de Instancias')

ax_test.hist(length_train,  color = 'red', edgecolor = 'black',
         bins = int(300/15))
ax_test.set_title('Conjunto test')
ax_test.set_xlabel('Tamaño')
ax_test.set_ylabel('Número de Instancias')

# Add labels
plt.title('Distribución de la longitud de los textos')
plt.xlabel('Tamaño (tokens)')
plt.ylabel('Número de textos')
# Out:
# Text(0, 0.5, 'Número de textos')

# %% [markdown]
# **Representación de textos**
#
# La entrada del algoritmo de clasificación son los textos, pero estos deben ser representados como vectores de números reales. Antes de realizar esta transformación, hay que incluir algunas tareas de limpieza de los textos, eliminando palabras y símbolos que no aporten información semántica para la clasificación:

# %%
nltk.download('stopwords')
nltk.download('punkt')

stopwords_es = stopwords.words("spanish")

def clean_text(text):
    # transformar a minúscula
    text=str(text).lower()
    # tokenizar
    tokens=word_tokenize(text)
    # borrar stopwords
    tokens = [word for word in tokens if word not in stopwords_es]
    # usar los stems
    tokens = [PorterStemmer().stem(word) for word in tokens]
    # eliminamos las palabras con menos de 3 caráceres
    # ignoramos cualquier palabra que contenga un digito o un símbolo especial 
    min_length = 3
    p = re.compile('^[a-zA-Z]+$');
    filtered_tokens=[]
    for token in tokens:
        if len(token)>=min_length and p.match(token):
            filtered_tokens.append(token)
            
    return filtered_tokens
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %% [markdown]
# **tf-idf**

# %%
# entrenamos un modelo de bolsa de palabras
bow = CountVectorizer(analyzer=clean_text).fit(X_train)
# transformamos el conjunto de entrenamiento a bolsa de palabras
X_train_bow = bow.transform(X_train)
# transformamos el conjunto de evaluación a bolsa de palabras
X_test_bow=bow.transform(X_test)


# entrenamos un modelo tf-idf 
tfidf_transformer = TfidfTransformer().fit(X_train_bow)
# transformamos el conjunto de entrenamiento
X_train_tfidf = tfidf_transformer.transform(X_train_bow)
# transformamos el conjunto de entrenamiento
X_test_tfidf = tfidf_transformer.transform(X_test_bow)

print('textos han sido representados con el modelo tf-idf ')
# Out:
# textos han sido representados con el modelo tf-idf

# %%
print(X_train[0])
print(X_train_bow[0])
print(X_train_tfidf[0])
# Out:
# ¡Feliz 28 de febrero a todas las andaluzas y andaluces!. Por una Andalucía donde el presente, y el futuro, sea sinónimo de derechos, de igualdad plena, de trabajo estable y con condiciones dignas. Una Andalucía de nuevas oportunidades, de esperanza.
#   (0, 5735)	1
#   (0, 39031)	1
#   (0, 39031)	0.2400950776314681
#   (0, 5735)	0.970749377386944

# %% [markdown]
# **Clasificación**

# %%
pipeline = Pipeline([
    ('bow', CountVectorizer(analyzer=clean_text)),  
    ('tf', TfidfTransformer()),  
    ('svm', SVC()), 
])

# Parámetros para el algoritmo SVM
grid_params_svm = [{'svm__kernel': ['linear', 'rbf'], 
                    'svm__C': [0.1, 1], 
                    
                    }]  

  
gs = GridSearchCV(pipeline, param_grid=grid_params_svm, 
                  scoring='accuracy', cv=3, verbose = 1)

# entrenamos el grid
gs.fit(X_train, y_train)
print('Los mejores parámetros son : %s' % gs.best_params_)
print('Mejor accuracy: %.3f' % gs.best_score_)
print(gs.best_estimator_)
# Out:
# Fitting 3 folds for each of 4 candidates, totalling 12 fits
# Los mejores parámetros son : {'svm__C': 1, 'svm__kernel': 'rbf'}
# Mejor accuracy: 0.481
# Pipeline(steps=[('bow',
#                  CountVectorizer(analyzer=<function clean_text at 0x7f4dd0f9d480>)),
#                 ('tf', TfidfTransformer()), ('svm', SVC(C=1))])

# %%
predictions = gs.predict(X_test)

# %%
print( classification_report(y_test, predictions))
# Out:
#                 precision    recall  f1-score   support
#
#           left       0.55      0.15      0.24      1920
#  moderate_left       0.48      0.77      0.59      4164
# moderate_right       0.49      0.49      0.49      3468
#          right       0.69      0.07      0.13      1248
#
#       accuracy                           0.49     10800
#      macro avg       0.56      0.37      0.36     10800
#   weighted avg       0.52      0.49      0.44     10800

# %%
binary_labels = ["left", "moderate_left", "moderate_right", "right"]
fig = plt.subplots(figsize = (7, 7))
cm_dtc1 = confusion_matrix(y_test, predictions, normalize = "true")
sb.heatmap(cm_dtc1, vmin = 0, vmax = 1, square = True, annot = True, fmt = ".2f", cbar_kws = {"shrink" : 0.5}, xticklabels = binary_labels, yticklabels = binary_labels)
plt.title("Matriz de confusión")
plt.xlabel("Valores predichos")
plt.ylabel("Valores reales")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.metrics import confusion_matrix

binary_labels = ["left", "moderate_left", "moderate_right", "right"]
fig, ax = plt.subplots(figsize=(7, 7), dpi=600)
cm_dtc1 = confusion_matrix(y_test, predictions, normalize="true")
sb.heatmap(cm_dtc1, vmin=0, vmax=1, square=True, annot=True, fmt=".2f", cbar_kws={"shrink": 0.5}, xticklabels=binary_labels, yticklabels=binary_labels)
plt.title("Matriz de confusión")
plt.xlabel("Valores predichos")
plt.ylabel("Valores reales")
plt.savefig("confusion_matrix.png", dpi=600)
plt.show()

# %%
y_test2=np.array(y_test)
# Step 4: Analyze incorrect predictions

incorrect_indices = [i for i in range(len(y_test2)) if y_test2[i] != predictions[i]]
incorrect_samples = [df_cb.iloc[i]['text'] for i in incorrect_indices]
incorrect_true_labels = [y_test2[i] for i in incorrect_indices]
incorrect_predicted_labels = [predictions[i] for i in incorrect_indices]


c = 0
# Step 5: Investigate the misclassified samples
for sample, true_label, predicted_label in zip(incorrect_samples, incorrect_true_labels, incorrect_predicted_labels):
    # Analyze the misclassified sample and relevant information
    print(f'Sample: {sample}')
    print(f'True Label: {true_label}')
    print(f'Predicted Label: {predicted_label}')
    print("---")
    c = c + 1
# Out:
# Streaming output truncated to the last 5000 lines.
# Sample: El presidente solo está para cobrar el sueldo de presidente, no tiene responsabilidad alguna.
# True Label: moderate_right
# Predicted Label: moderate_left
# ---
# Sample: Interesante la serie El pacto de HBO. Tiene ese clásico aroma británico, un buen guion y sobre todo muy entretenida.
# True Label: right
# Predicted Label: moderate_right
# ---
# Sample: 🗞Comparto la entrevista que realizamos con @user . 👉🏼 “Nosotros entendemos que la progresividad fiscal es la que permite la justicia social, pero una justicia bien entendida, los que menos tienen, tienen que aportar menos”. Léela completa aquí:
# True Label: moderate_right
# Predicted Label: moderate_left
# ---
# Sample: 👏🏼¡La gastronomía riojana es estelar! Enhorabuena, Mariana [POLITICIAN], Gonzalo Baquedano y todo el equipo del [HASHTAG] por esta merecida ⭐️ Michelín! .
# True Label: moderate_right
# Predicted Label: moderate_left
# ---
# Sample: 👏🏼🏆Querida Rosa Castellot, ha sido todo un honor poder entregarte este galardón de las Artes y la Cultura de [HASHTAG] como reconocimiento a tu labor, desde ‘Arte en la Tierra’ en nuestro Valle de Ocón hasta tu desempeño como maestra. Muchas felicidades y gracias por tu arte
# True Label: left
# Predicted Label: moderate_left
# ---
# Sample: 🍇 [HASHTAG] impulsará de manera integral la transformación sostenible, verde y digital de la cadena de valor del vino. Queremos convertir [HASHTAG] en referente absoluto en la industria, en el conocimiento y en el turismo del vino.
# True Label: left
# Predicted Label: moderate_right
# ---
# Sample: 👏🏻¡Las puertas de [HASHTAG] están abiertas al turismo, a la cultura y al buen vino!. La Asociación de Mujeres lleva 25 años organizando un evento que enriquece a la . ¡Gracias! Es una gozada ver el compromiso y orgullo que demuestran por enseñar las riquezas del municipio.
# True Label: left
# Predicted Label: moderate_right
# ---
# Sample

# True Label: moderate_left
# Predicted Label: moderate_right
# ---
# Sample: @user Pero tiene truco, igual los manifestantes dejadeces son policías jubilados ya un poco cascadetes, con su codo de porrista.
# True Label: left
# Predicted Label: moderate_left
# ---
# Sample: @user Piensas peor que pones tildes, meningítico mental y gramatical. Venga, que no das ni para unas risas por lo cortimer que eres.
# True Label: moderate_left
# Predicted Label: moderate_right
# ---
# Sample: @user Lo es, y se va haciendo aún más grande con el tiempo.
# True Label: left
# Predicted Label: moderate_left
# ---
# Sample: @user Hecha desde la azotea del Ayuntamiento y con un móvil. Ni una aérea.
# True Label: moderate_right
# Predicted Label: moderate_left
# ---
# Sample: Que alguien con mejor habilidad psicomotriz y gráfica que yo cumpla mi sueño, solo os pido.
# True Label: left
# Predicted Label: moderate_left
# ---
# Sample: El mejor slogan electoral que ha tenido el [POLITICAL_PARTY] en su historia.
# True Label: left
# Predicted Label: moderate_left
# ---
# Sample: Primero asaltaron el Congreso los ultras de Trump. Después asaltan el Congreso los ultras de Bolsonaro. ¿No hay dos sin Tertsch?
# True Label: moderate_right
# Predicted Label: right
# ---
# Sample: Pues al final sí era verdad que el [POLITICAL_PARTY] se iba a cambiar de sede.
# True Label: right
# Predicted Label: moderate_left
# ---
# Sample: @user Y yo. Si alguien lo sabe, que se manifieste.
# True Label: moderate_left
# Predicted Label: moderate_right
# ---
# Sample: Una nueva forma de protesta en Irán:. Cada vez más mujeres jóvenes se graban quitando de un golpe los turbantes a los clérigos en plena calle para demostrarles que les han perdido el respeto y el miedo. Bravas. [HASHTAG].
# True Label: left
# Predicted Label: moderate_left
# ---
# Sample: Veo que es tendencia Felipe González porque el [POLITICAL_PARTY] lo usa como ejemplo de socialista. Sólo vengo a recordar esto de Daniel Guzmán
# True Label: right
# Predicted Label: moderate_right
# ---
# Sample: Si alguien se quiere currar el meme con esta foto, no seré yo quien ponga ninguna pega. ;)
# True Label: moderate_right
# Predicted Label: moderate_left
# ---
# Sample: @user Cierto, lo intento, pero a veces es inevitable. Mea culpa.
# True Label: left
# Predicted Label: moderate_right
# ---
# Sample: @user Siempre hay que avivar esa hoguera, que ya le queda poco.
# True Label: left
# Predicted Label: moderate_left
# ---
# Sample: @user Otro que mira el dedo cuando le señalan la Luna.
# True Label: left
# Predicted Label: moderate_right
# ---
# Sample: @user Por hacer un homenaje a su mítica foto con el narco, yo lo mediría en gramos.
# True Label: moderate_right
# Predicted Label: moderate_left
# ---
# Sample: @user He hecho literalmente una broma con la columna, no me voy a tomar en serio a alguien que no se lo toma a sí mismo. ;)
# True Label: right
# Predicted Label: moderate_left
# ---
# Sample: @user No descarto. Aunque policía tampoco he visto apenas, ni SAMUR. Curioso.
# True Label: moderate_right
# Predicted Label: moderate_left
# ---
# Sample: Lucía Etxebarria indignada por no haber ganado el Nobel de Literatura cuando tiene un libro suyo exactamente igual que el de la ganadora Annie Ernaux.
# True Label: left
# Predicted Label: moderate_right
# ---
# Sample: @user Busca tarjetas black y Froilán en google, nunca viene mal la información de la financiación de la Casa Real, que sepamos.
# True Label: moderate_right
# Predicted Label: moderate_left
# ---
# Sample: De los dos con la mancha esa rara encima que intentaban cargarse el comunismo, va y se muere Gorbachov.
# True Label: moderate_right
# Predicted Label: moderate_left
# ---
# Sample: El del medio de Los Chichos. Se me ha "aparecío" en sueños. Se me ha "aparecío" y me ha dicho. De tu Congreso soy el dueño.
# True Label: right
# Predicted Label: moderate_left
# ---
# Sample: “La violación de los derechos humanos no es algo que deba involucrarme, vine a disfrutar de la vida”. Maluma haciéndose un Marlaska.
# True Label: moderate_right
# Predicted Label: moderate_left
# ---
# Sample: @user Entre la gente, algunos con problemas de movilidad, que quiere -y tiene todo su derecho- a utilizar esa acera pública JUSTO por ahí y el empresario que se la ha cerrado por la face, adivinad con quien empatiza Asier. ;)
# True Label: moderate_right
# Predicted Label: moderate_left
# ---
# Sample: @user Vas con retraso, con lo del bulo de Antonio también. A partir de ahí ya todo cuesta abajo y sin frenos al cuñadismo ultra de cabeza. ;)
# True Label: moderate_left
# Predicted Label: left
# ---
# Sample: @user Sabía que te iba a flipar. Mañana comentamos y seguimos dándole forma a lo que se puede y se debe hacer. ;)
# True Label: left
# Predicted Label: moderate_left
# ---
# Sample: @user Sería muy poético que la ultraderecha nos dejara sin curas en España.
# True Label: left
# Predicted Label: moderate_left
# ---
# Sample: La primera regla de la cortina de humo:. La barbaridad que digas tiene que ser proporcional a la barbaridad que intentas ocultar.
# True Label: right
# Predicted Label: moderate_right
# ---
# Sample: El “Borboning”, no haber usado las manos para nada relacionado con el trabajo.
# True Label: moderate_right
# Predicted Label: moderate_left
# ---
# Sample: @user Pues mira, ya tienen una facha menos en tu país, irán avanzando. ;)
# True Label: left
# Predicted Label: moderate_left
# ---
# Sample: Lo facha que se ha vuelto Sam desde que dejó la Comunidad del Anillo.
# True Label: left
# Predicted Label: moderate_left
# ---
# Sample: @user Mucha más credibilidad “el Jueves” que cómo contabiliza las listas de espera la Comunidad de Madrid. Aunque también son una broma. ;)
# True Label: right
# Predicted Label: moderate_right
# ---
# Sample: @user Culparemos a monguers como tú, tenemos claras nuestras prioridades, no te preocupes. ;)
# True Label: left
# Predicted Label: moderate_left
# ---
# Sample: Pues ya estamos en quién la tiene más grande otra vez (la espada).
# True Label: moderate_right
# Predicted Label: moderate_left
# ---
# Sample: ¡Atentado a la democracia!. Todo el santo dia unos y otros. No, no es equidistancia, es agotamiento de una clase política generadora de problemas en vez de soluciones.
# True Label: left
# Predicted Label: moderate_left
# ---
# Sample: [POLITICAL_PARTY] ha entrado en la fase Podemos de atacar a los que consideraban medios de comunicación amigos y señalando a periodistas que ya no son “buenos”. Empiezan fuerte, con Federico.
# True Label: right
# Predicted Label: moderate_right
# ---
# Sample: “Sumar no es fácil” “pues un poco de música ambiente no vendría mal” “que entre ya que nos quemamos”. Las pantallas empiezan a emitir fotos de Yolanda. Empiezan los aplausos. Sol abrasador en la Plaza Matadero
# True Label: moderate_right
# Predicted Label: moderate_left
# ---
# Sample: Los magistrados del TC han estado más de 10 horas debatiendo pero tú tienes la razón y la verdad en un tweet.
# True Label: right
# Predicted Label: left
# ---
# Sample: Como serán las “indirectas” de Shakira que hasta los tíos las estamos pillando…
# True Label: moderate_right
# Predicted Label: moderate_left
# ---
# Sample: La nueva de BlackPanther me dejó un poco indiferente. Como si hubiera visto una versión de Avatar2 sin 3D…
# True Label: moderate_left
# Predicted Label: moderate_right
# ---
# Sample: Pide [POLITICIAN] una “Democracia económica que llegue a los impuestos”. “Hay una inflación que nos ahoga por eso los impuestos son más necesarios que nunca”. “Un autónomo no puede pagar más impuestos que una multinacional”. “La democracia tiene que llegar a las empresas”
# True Label: right
# Predicted Label: moderate_left
# ---
# Sample: La verdad es que contra @user ya lo han intentado todo.
# True Label: left
# Predicted Label: moderate_left
# ---
# Sample: Que una/la sentencia fuera más que cuestionable no exculpa de que ENCIMA se rebaje la pena por semejante error en la ley.
# True Label: moderate_left
# Predicted Label: moderate_right
# ---
# Sample: La modificación de la malversación no puede sonar peor, hasta que llega un nuevo día y lo superan…
# True Label: right
# Predicted Label: moderate_left
# ---
# Sample: @user Ojo que con el “procés”… entramos en debate profundo ;)
# True Label: right
# Predicted Label: left
# ---
# Sample: Mira que le pido a Euprepio que me deje alguna vez sus chaquetas pero se sigue negando… con esta no pararé hasta que me la pase un día ;)
# True Label: moderate_left
# Predicted Label: moderate_right
# ---
# Sample: Ayer vi a un santero (sí, existen) que se montaba en un Dacia Sandero. Me pareció un ejercicio de coherencia fónica que merecía este espacio.
# True Label: left
# Predicted Label: moderate_left
# ---
# Sample: Una reducción de la población que es por voluntad/elección/adaptación a situación económica y social es lógica especialmente cuando la esperanza de vida aumenta y las tasas de superviviencia infantiles son realmente elevadas. Tendemos a disfrutar más cualitativamente.
# True Label: left
# Predicted Label: moderate_left
# ---
# Sample: Pues que les pongan una amarilla. Nunca fue tan fácil hacer lo mínimo.
# True Label: right
# Predicted Label: moderate_right
# ---
# Sample: ¡Ya puedes escucharlo! Analizamos históricamente “El discurso del Rey”
# True Label: left
# Predicted Label: moderate_left
# ---
# Sample: Malversar es malversar. El lucro llega de mil formas diferentes. Si hay un dinero de todos los ciudadanos para una cosa, no se puede desviar a otra por la voluntad personal de alguien y sin saber los motivos, los destinos ni las causas. Es dinero de todos ¡leches!
# True Label: left
# Predicted Label: moderate_left
# ---
# Sample: En lineas generales la campaña electoral en Andalucía ha sido mala por todos los partidos. Hasta [POLITICAL_PARTY] ha estado muy por debajo de las expectativas creadas con [POLITICIAN] (No hablo de resultados… todavía). Sin campañas buenas suele ser premio para el que gobierna.
# True Label: right
# Predicted Label: moderate_left
# ---
# Sample: ¿Quieren que Yolanda defienda a Irene o que Yolanda se pringue con Irene?
# True Label: left
# Predicted Label: moderate_left
# ---
# Sample: Si te denuncia la derecha no vale porque son de derechas… y tampoco se tolera que alguien de izquierdas denuncie posibles delitos porque es hacerle el juego a la derecha. Vamos, que inmunidad absoluta.
# True Label: moderate_right
# Predicted Label: moderate_left
# ---
# Sample: Que el 30%… o más… de los usuarios de transporte público ya no llevan mascarilla… ¿lo tenemos asumido, no?
# True Label: left
# Predicted Label: moderate_left
# ---
# Sample: @user Ese es el problema, que quien tiene que denunciar los excesos de [POLITICIAN], está así.
# True Label: right
# Predicted Label: moderate_right
# ---
# Sample

# True Label: moderate_left
# Predicted Label: moderate_right
# ---
# Sample: Más allá del Debate sobre el Estado de la Nación, las facturas siguen llegando y la comparación entre el año pasado y este es para seguir temblando. ¡¡¡+ de 63€ de aumento por lo mismo!!!
# True Label: moderate_left
# Predicted Label: moderate_right
# ---
# Sample: Está siendo un poco agónico el adelantamiento de Lula a Bolsonaro, pero seguro ;)
# True Label: moderate_right
# Predicted Label: right
# ---
# Sample: Como ella no anda por aquí, os lo cuento yo.
# True Label: right
# Predicted Label: moderate_left
# ---
# Sample: @user Qué suerte que me acompañes en esta presentación.
# True Label: left
# Predicted Label: moderate_right
# ---
# Sample: @user Muchas felicidades de parte de Edurne y mía. Qué alegría ver todo el reconocimiento que estás recibiendo.
# True Label: moderate_right
# Predicted Label: moderate_left
# ---
# Sample: @user En alemán pescado azul es Fettfisch, pero casi nadie hace la distinción.
# True Label: moderate_right
# Predicted Label: moderate_left
# ---
# Sample: Hacía años que no visitaba la Thyssen, pero siempre que lo hago busco a mi muerto viviente favorito. Es impresionante.
# True Label: right
# Predicted Label: moderate_left
# ---
# Sample: @user Qué bonito que hayas estado tú ahí.
# True Label: moderate_right
# Predicted Label: moderate_left
# ---
# Sample: Para no aburriros cada vez con mis actividades, pero por si os interesa, dejo un pantallazo de mi agenda de sept. y oct., centrada en "Mientras estamos muertos" y "Aufstand" ("Insurrección"): Madrid, Zaragoza, Lleida, Valencia, Alemania y Suiza. Allí me encontraréis, si queréis.
# True Label: left
# Predicted Label: moderate_left
# ---
# Sample: @user Gracias por la reseña, Eva. Muy bonita, y destacas los dos relatos que yo también destacaría 🙂
# True Label: moderate_right
# Predicted Label: moderate_left
# ---
# Sample: Teniendo en cuenta que en España su partido tacha al Gobierno de ilegítimo y que, junto con sus socios de [POLITICAL_PARTY], acusan de golpe de Estado a [POLITICIAN], no me queda claro si @user está condenando a los atacantes o al Gobierno de Lula. ¿Nos lo podría aclarar?
# True Label: right
# Predicted Label: moderate_right
# ---
# Sample: Si os estáis pensando si dar a E. Musk 8 euros para que pueda salvar a la humanidad, mejor donadlos a la campaña para salvar el periodismo independiente de La Marea. De verdad, van a ser más beneficiosos aquí que en manos del magnate. Solo quedan 4 días.
# True Label: right
# Predicted Label: moderate_left
# ---
# Sample: @user Gracias por la explicación. Este año llego tarde 🙂🙂
# True Label: left
# Predicted Label: moderate_left
# ---
# Sample: @user La pena es que no habrá compensación por el daño político y personal que hicieron, él y sus cómplices. Pero de todas maneras me alegro.
# True Label: left
# Predicted Label: moderate_right
# ---
# Sample: @user Pues para ser fiestas, qué serio te pones 🙂🙂
# True Label: left
# Predicted Label: moderate_left
# ---
# Sample: @user Querido Dani, entonces la admiración es mutua. Es un privilegio trabajar contigo.
# True Label: right
# Predicted Label: moderate_left
# ---
# Sample: Me apetecía mucho grabar este audiolibro. Espero que os guste.
# True Label: right
# Predicted Label: moderate_right
# ---
# Sample: @user A mí me cambió la manera de leer y de entender la literatura.
# True Label: moderate_right
# Predicted Label: moderate_left
# ---
# Sample: @user Pero ¿cómo que de la generación de nuestros padres? 😱😱
# True Label: moderate_right
# Predicted Label: moderate_left
# ---
# Sample: Santiago Ramón y Cajal, diseñador; R. Padró, pintor. Esquema de la estructura del cerebelo, ca. 1900. En La Nau, Valencia.
# True Label: right
# Predicted Label: moderate_left
# ---
# Sample: @user Mantennos informados 🙂. Este año no estamos... pero volveremos.
# True Label: left
# Predicted Label: moderate_left
# ---
# Sample: @user Gracias por la lectura y por la reseña. Me alegra que te haya gustado "Mientras estamos muertos".
# True Label: moderate_right
# Predicted Label: moderate_left
# ---
# Sample: Es excepcional que alguien escriba una obra maestra de novela corta y otra de novela (muy) larga. Melville lo hizo.
# True Label: moderate_left
# Predicted Label: moderate_right
# ---
# Sample: @user Justo de esto hablo. Como sus acciones molestan, las descalificamos sin mucho fundamento. "Tengo entendido..." ¿Quién lo dice? ¿Son Rockefeller, son Kennedy? ¿Cuál de ellos? ¿Tienen intereses en el petróleo? La realidad de su financiación es más compleja.
# True Label: left
# Predicted Label: moderate_left
# ---
# Sample: Japón no existe. Pero @user y Javier Vela han escrito dos libros maravillosos relacionados con la cultura de ese país. @user .
# True Label: moderate_right
# Predicted Label: moderate_left
# ---
# Sample: @user He entrado a su página web y el lenguaje es de secta tecnológica. Conozco bien la zona, porque voy con cierta frecuencia a Valdecaballeros.
# True Label: left
# Predicted Label: moderate_left
# ---
# Sample: @user Muchas gracias, Éxtasis. Y si además tienes una foto de perfil con Leonard Cohen, la conexión es aún mayor 🙂🙂
# True Label: moderate_left
# Predicted Label: moderate_right
# ---
# Sample: @user No he mirado la lista, ni sentía curiosidad. Y ahora que dices que no hay un solo libro de relatos, menos aún
# True Label: right
# Predicted Label: left
# ---
# Sample: De esto mismo estaremos hablando con @user en la @user la mañana de Navidad. Con @user  @user  @user y Lorenzo Silva.
# True Label: moderate_right
# Predicted Label: moderate_left
# ---
# Sample: @user Ya, el otoño va a ser intenso. Y ojalá ese encuentro, que hace un montón que no nos vemos. Besos.
# True Label: left
# Predicted Label: moderate_left
# ---
# Sample: @user En Bolonia, el fresco del infierno en San Petronio.
# True Label: right
# Predicted Label: moderate_right
# ---
# Sample: @user Que sí, que de vez en cuando hay muy buenas noticias. Y, como dice el título de un cuento de Onetti: Bienvenido, Bob.
# True Label: left
# Predicted Label: moderate_left
# ---
# Sample: @user Meridiano de sangre es obra cumbre. Le dediqué un capítulo en "La ética de la crueldad". He leído otras de él, pero, gustándome todas, ninguna me produjo el mismo entusiasmo.
# True Label: right
# Predicted Label: moderate_left
# ---
# Sample: Uno de los actos que más ilusión me hacen en esta gira alemana es la presentación de "Aufstand" ("Insurrección") en el Gängeviertel, barrio histórico de Hamburgo cuyo derribo definitivo fue evitado por una okupación.
# True Label: left
# Predicted Label: moderate_left
# ---
# Sample: Os recomiendo mucho la última novela de Pablo Gutiérrez, "La tercera clase", en @user
# True Label: left
# Predicted Label: moderate_right
# ---
# Sample: @user Qué pedazo reseña. Ni me había enterado. Gracias por compartirla, Pere.
# True Label: moderate_right
# Predicted Label: moderate_left
# ---
# Sample: ¿Sabéis lo que más me emociona del crowdfunding de La Marea? Esa gente que da 1, 2, 5 euros, esa gente que está diciendo: no tengo dinero, pero no me quedo sin apoyar el periodismo que hacéis.
# True Label: moderate_right
# Predicted Label: moderate_left
# ---
# Sample: @user ¿Por qué da lo mismo la desigualdad global? Importan ambas, ¿pero global más, ¿no?. La desigualdad intra país aumenta en bastantes países ricos/occidentales. Pero en general también? Es pregunta genuina. Sé por ejemplo que se reduce en países latam. No sé en Asía o Africa.
# True Label: left
# Predicted Label: moderate_right
# ---
# Sample: @user Justo, no está clasificada, depende de los goles. Es solo que es raro y en redondeo de 100.000 sims no es eliminada. Mañana lo preciso :)
# True Label: right
# Predicted Label: moderate_left
# ---
# Sample: Pero tampoco vale solo con técnica. Los coches autónomos tendrán que resolver dilemas éticos inescapables ⚖️:. «¿Debo golpear el vehículo que viene de frente para esquivar a un peatón despistado que tiene probabilidad 30% de cruzar sin mirar?»
# True Label: moderate_right
# Predicted Label: moderate_left
# ---
# Sample: 🚗 23. En China los coches totalmente eléctricos ya son el 30% de todos los nuevos. Es el doble que hace un año. @user
# True Label: right
# Predicted Label: moderate_left
# ---
# Sample: @user Sí, mi sensación es que hacerlo más factual —no 100% factual— no será tan difícil. Además, ahora no tiene internet.
# True Label: left
# Predicted Label: moderate_left
# ---
# Sample: Detalles random: España y Portugal se nos cambian de orden por error de redondeo. Haciendo 100.000 mundiales, nos queda uno u otro delante indistintamente.. El modelo juzga que España es un poco mejor, pero que tiene un grupo/cruces un poco más difíciles.
# True Label: moderate_right
# Predicted Label: moderate_left
# ---
# Sample: — ¿Quieres saber más?. ¡Mira el índice! Las 8 reglas se dividen en capítulos, y cada capítulo explica unas ideas: sobre complejidad, causalidad, patrones ilusorios, trade-offs, sesgos de colisión, malas apuestas, etc. Aquí va:. 🔗
# True Label: left
# Predicted Label: moderate_left
# ---
# Sample: @user Es difícil hacer una lista exhaustiva y común. Un atajo: si fueses a nacer en cierto año y ser una persona al azar, ¿qué año elegirías para ti o para tus hijos? Yo elegiría 2023.
# True Label: left
# Predicted Label: moderate_left
# ---
# Sample: @user Puede ser. Mi punto es que quizá prefiero la gente que se *siente* impostora a quienes se creen omnipotentes. Al menos me caen mejor.
# True Label: right
# Predicted Label: moderate_left
# ---
# Sample: Era una encuesta con dos preguntas:. 1️⃣ Primero te preguntaba cuál es tu estación favorita: primavera, verano, otoño o invierno. 2️⃣ Luego, en otra pantalla, te pedía la fecha de tu cumpleaños.
# True Label: right
# Predicted Label: moderate_left
# ---
# Sample: @user Es uni. Esa sería una vía de mejora, también para modelar goles a favor y en contra, que en nuestro torneo importa poco, pero en otro tipo de competiciones -ida y vuelta- creo que puede ser relevante. La mejora principal, de todos modos, es alimentar de más datos de equipos.
# True Label: moderate_left
# Predicted Label: left
# ---
# Sample: Consulta: ¿Alguien conoce especialistas o empresas que se dediquen al peritaje estadístico? Para presentar denuncias o sostener en juicios o en negociaciones hechos estadísticamente normales, raros, probables, etc.. (DM abiertos)
# True Label: right
# Predicted Label: moderate_left
# ---
# Sample: Pues creo que ya tengo equipo en Premier: del Arsenal, por lo menos mientras juegue Ødegaard.
# True Label: moderate_right
# Predicted Label: moderate_left
# ---
# Sample: — La salud mental nos preocupa más que nunca, pero las crecientes tasas de ansiedad, por ejemplo, también son el reflejo de una mayor conciencia: algo está cambiando —a mejor— para que demos el mismo estatus a la salud mental y física.
# True Label: left
# Predicted Label: moderate_right
# ---
# Sample: @user A mi el primero me gustó sólo normal también. Pero dicen que mejora y confío en la buena recepción de fans del juego :)
# True Label: right
# Predicted Label: moderate_left
# ---
# Sample: @user Hice un formulario separado sencillo. Solo soy lector de Metaculus y no quise complicar, pero estaría bien por tener directamente medias públicas y demás.
# True Label: moderate_right
# Predicted Label: moderate_left
# ---
# Sample: @user Jaja, tienes razón. A ver… Puedo defender el periodismo en general o criticar académicos por diferentes cosas, aunque me temo que estaremos de acuerdo en mucho. Le doy una vuelta :)
# True Label: left
# Predicted Label: moderate_left
# ---
# Sample: ¿Quién ganará las elecciones? ¿Y LaLiga? ¿Seguirá Elon Musk siendo el dueño de Twitter? ¿La desigualdad subirá o bajará?. 🧵. Mis 62 predicciones para 2023
# True Label: moderate_right
# Predicted Label: left
# ---
# Sample: @user Sí, es súper consistente entre subgrupos. Había algún patrón —la izquierda más pesimista—, pero poca cosa.
# True Label: moderate_left
# Predicted Label: moderate_right
# ---
# Sample: @user No hemos publicado estos datos, no. Podemos valorar aunque en realidad son fuentes abiertas: Eloratings y Transfermarkt.
# True Label: moderate_right
# Predicted Label: left
# ---
# Sample: C • ¿Cuál de las cuatro imágenes anteriores te gusta y te evoca el VERANO?
# True Label: right
# Predicted Label: moderate_left
# ---
# Sample: @user Sí, como hay un favorito, el resto se tienen que repartir casi un puesto entre tres, y tocan a menos de 50% probabilidad.
# True Label: right
# Predicted Label: moderate_left
# ---
# Sample: @user Sí aporte fuentes, en mi tuit hay un link que quizá no viste. En cuanto a China, 1) “mundial” los incluye, claro; 2) ¿por qué iba a excluirla?, 3) tu propio párrafo dice que, incluso ignorando a China, en el resto del mundo también se reduce.
# True Label: moderate_left
# Predicted Label: moderate_right
# ---
# Sample: @user ¡Gracias! El mundial es en verdad una trampa para escribir sobre esas cosas :)
# True Label: moderate_right
# Predicted Label: moderate_left
# ---
# Sample: @user No hay que elegir un extremo. La jerarquización no está en peligro, pero, por ejemplo: ¿no estaría bien que te recibiese al entrar en app/web los artículos de tus autores favoritos? ¿O un tema de anteayer sobre un asunto que te interesa?
# True Label: right
# Predicted Label: moderate_right
# ---
# Sample: Las diferencias son también evidentes por países. Francia es el país más laureado, con 11 ganadores, seguido de Estados Unidos (9) y Alemania (8).. El jurado sueco también le ha dado el premio a siete compatriotas 🤔
# True Label: moderate_right
# Predicted Label: moderate_left
# ---
# Sample: @user ¿Mal por qué? De todos modos, hay 1.300 para remontar el arranque.
# True Label: moderate_right
# Predicted Label: moderate_left
# ---
# Sample: @user En este caso es todo Opta, usamos también a menudo @user  @user . Y @user y @user  por ejemplo. Hay algunos datos en abierto, muchos que no. Bruto es especialmente raro, diría :)
# True Label: moderate_right
# Predicted Label: moderate_left
# ---
# Sample: @user Muchas gracias, Miquel. Por leerlo y por compartir que te gustó, el boca a boca es el éxito de un libro así :)
# True Label: left
# Predicted Label: moderate_left
# ---
# Sample: Obama tomaba decisiones firmes y luego descansaba por las noches, no por sentirse infalible, sino porque confiaba en una mezcla de buena voluntad y frío método. Tenía una mirada sofisticada del mundo, que no era ni de ciencias ni de letras, sino híbrida.
# True Label: moderate_right
# Predicted Label: moderate_left
# ---
# Sample: @user Muchas gracias, Carlos. Por hacerse con el libro y por compartirlo :)
# True Label: right
# Predicted Label: moderate_left
# ---
# Sample: El modelo predice en detalle los grupos. Este es el de España. Será primera con probabilidad 49% y segunda con 33%. ¿Su eliminación? No debería pasar más que un 17% de las veces: como lanzar un dado y sacar 1.
# True Label: left
# Predicted Label: moderate_left
# ---
# Sample: En el Senado hay cuatro estados por decidir, con dos la clave: Georgia (demócrata con 57% probabilidad) y Nevada (54%). Los demócratas solo necesitan uno para mantener el control del Senado en 50-50.
# True Label: moderate_left
# Predicted Label: moderate_right
# ---
# Sample: ¿Qué tan exacto ha sido nuestro modelo en comparación con otras predicciones?. ¡Lo hizo bien! Nuestro Brier fue de 0.20, que es mucho mejor que predecir al azar (0.25) y que también mejoró (o igualó) a las apuestas y a los modelos de FiveThirtyEight y Opta.
# True Label: left
# Predicted Label: moderate_left
# ---
# Sample: @user Muchísimas gracias por recomendarlo, Agus. Qué bueno que te gustase.
# True Label: right
# Predicted Label: moderate_right
# ---
# Sample: @user No en esta historia —lo barajamos, pero acabó cayendo—, aunque había cosas interesantes en
# True Label: moderate_right
# Predicted Label: moderate_left
# ---
# Sample: 🏆📊 ¿Qué tal funcionó nuestra predicción del Mundial?. Hoy le hago un rápido post-mortem con @user . Lo mejor es que el modelo interesó a muchos lectores que volvían cada día a verlo actualizar :). Pero, ¿cumplió el modelo su promesa? Va hilo 🧵
# True Label: right
# Predicted Label: moderate_right
# ---
# Sample: “La verdad siempre ha sido un producto más complejo de lo que el mercado puede empaquetar y vender fácilmente.”. ~ Naomi Alderman
# True Label: right
# Predicted Label: moderate_right
# ---
# Sample: @user Muchas gracias, Ramiro. Qué alegría que te haya gustado :)
# True Label: moderate_left
# Predicted Label: moderate_right
# ---
# Sample: De los langostinos a los polvorones: así ha subido el precio de la cena de Navidad, plato a plato. Noticias regulares, pero estupendamente presentadas, por @user  @user y @user :.
# True Label: left
# Predicted Label: moderate_left
# ---
# Sample: @user ¡Muchas gracias! Qué bien que se lea deprisa además :) Yo también me compro algún libro siempre que compro otros para regalar.
# True Label: right
# Predicted Label: moderate_left
# ---
# Sample: @user Se usa desde discord. Es un poco lata, pero tiene gracia. Allí puedes ver también lo que va creando otra gente. También puedes probar dall-e, como te decía @user .
# True Label: left
# Predicted Label: moderate_left
# ---
# Sample: ¡¡Tápense un poco, sra. @user !!. Lo que NO se puede es cumplir la Constitución A TROZOS. ¡SÍ a la unidad territorial!. ¡SÍ a la división de poderes!. ¡SÍ al Estado de Derecho!. ¡SÍ a un Gobierno que respete la Constitución entera!
# True Label: left
# Predicted Label: moderate_left
# ---
# Sample: Gracias al @user  ha sido un honor compartir jornada de trabajo con ellos..
# True Label: left
# Predicted Label: moderate_right
# ---
# Sample: Señores @user e @user . ¿Pueden explicarle a los españoles de qué se ríe la señora secretaria de Estado de Igualdad?
# True Label: moderate_right
# Predicted Label: moderate_left
# ---
# ...
# True Label: moderate_right
# Predicted Label: moderate_left
# ---
# Sample: @user ¿De mojarlos y alimentarlos después de las doce qué dice? Porque ahí está el peligro...
# True Label: moderate_right
# Predicted Label: moderate_left
# ---
# Sample: De acosos bien y acosos mal, violencia mediática bien y violencia mediática mal.. Lección 1: afinar el tiro.
# True Label: moderate_right
# Predicted Label: moderate_left
# ---
# Sample: @user No tengo ni idea, yo también me lo pregunto. Lo tiene todo. ¡¡Si hasta el guionista de The Wire hizo hace años coña con eso en twitter!! (Y lo digo completamente en serio lo de que ahí hay una serie. Hazla, por dios)
# True Label: moderate_right
# Predicted Label: moderate_left
# ---
# Sample: @user A mí me habría jodido más el uso del pretérito imperfecto de indicativo delante de "un joven" que lo que trata de insinuar, Cristian. ¡¡Sigues siendo un joven periodista, hostias!!
# True Label: moderate_right
# Predicted Label: moderate_left
# ---
# Sample: @user jajajajjajaja ¡¡No sé qué haría sin ti, querida!! Lo apunto y ampliamos el artículo para alcanzar la excelencia en nuestra empresa. ¡LOF!
# True Label: left
# Predicted Label: moderate_left
# ---
# Sample: @user Dormir con el brazo recto hacia arriba no me parece cómodo. Como lo siento te lo digo.
# True Label: moderate_right
# Predicted Label: moderate_left
# ---
# Sample: @user ... quien está detrás de esa opinión o información. En redes o un blog me puede dar igual, pero en prensa no. Y a la hora de firmar un manifiesto, dónde alguien apoya una causa, hacerlo sin dar la cara no me parece la mejor de las maneras y me parece que resta seriedad y (sigo)
# True Label: moderate_right
# Predicted Label: moderate_left
# ---
# Sample: @user ... o la lista de tareas pendientes, ojo ahí.
# True Label: left
# Predicted Label: moderate_left
# ---
# Sample: A algunos se les olvida que la obligación de la prensa es fiscalizar a los poderes y creen que los medios están a su servicio. Enhorabuena a ABC y a @user por hacer periodismo y no propaganda.
# True Label: moderate_right
# Predicted Label: moderate_left
# ---
# Sample: @user Caballero, escriba su propia columna y ya si eso le leo...
# True Label: moderate_left
# Predicted Label: moderate_right
# ---
# Sample: ¡Menuda pataleta! Yo les sugeriría recurrir, en lugar de a la propaganda, a las acciones legales. A las informaciones veraces y documentadas, para desmontarlas, se les replica con la documentación requerida, no con las firmitas de los amigos y asalariados coronando una loa.
# True Label: moderate_left
# Predicted Label: moderate_right
# ---
# Sample: @user Estoy esperando viñeta, querido. Que lo sepas. Quiero viñeta aunque solo sea boceto y para estos ojitos.
# True Label: moderate_right
# Predicted Label: moderate_left
# ---
# Sample

# True Label: moderate_left
# Predicted Label: moderate_right
# ---
# Sample: Sube otra vez el SMI. Ya llega a los 1080€. Un 46% desde que echamos a [POLITICIAN]. Y el paro baja. Sucede lo contrario de lo vaticinado por la derecha.. Gracias @user .
# True Label: left
# Predicted Label: moderate_left
# ---
# Sample: [POLITICIAN] sólo puede gobernar con los del "volvemos al 36", y lo sabe.
# True Label: left
# Predicted Label: moderate_left
# ---
# Sample: ¿Saben quienes también querían que sus miembros tuvieran una pistola? Los de [POLITICAL_PARTY].
# True Label: left
# Predicted Label: moderate_left
# ---
# Sample: Se deshincha otro montaje de la Brigada de Información de Madrid contra una protesta ante el Congreso.. Teníamos razón. Lanzar agua y remolacha a una pared no es ningún atentado a las instituciones del Estado.
# True Label: left
# Predicted Label: moderate_left
# ---
# Sample: Llevamos empujando en esta ley más de un año. Y si cuesta tanto es por esto:.
# True Label: right
# Predicted Label: left
# ---
# Sample: Número de parados ➡️ por debajo de niveles prepandemia. Número de contratos indefinidos ➡️ disparado. La Reforma Laboral de @user sólo da buenos datos. Los economistas que vaticinaban el apocalipsis descubren que la tierra es redonda.
# True Label: left
# Predicted Label: moderate_left
# ---
# Sample: Nos presentamos a las elecciones exigiendo indultos, mesa de diálogo y reforma del Código Penal.. Hoy es un día para reconocer que, efectivamente, hemos avanzado. Pero todavía queda mucho trabajo por hacer. Seguimos. (3/3)
# True Label: right
# Predicted Label: moderate_left
# ---
# Sample: 1. El CGPJ lleva +4 años bloqueado por el [POLITICAL_PARTY]. 2. Nadie se fía de quien ha roto acuerdos. 3. Dos partidos (&lt;50% votos) no pueden ser los únicos en decidir. 4. Hay que impulsar una reforma para renovar el CGPJ con la pluralidad del Congreso. Esta anomalía europea debe acabar ya.
# True Label: moderate_left
# Predicted Label: moderate_right
# ---
# Sample: Es intolerable que el rey hable de aumentar el gasto militar. No puede tomar partido en un debate político. Debe ser neutral. Cuando expresa sus opiniones políticas, se sitúa fuera de la Constitución.
# True Label: moderate_left
# Predicted Label: moderate_right
# ---
# Sample: No hay libre mercado. Hay abuso y especulación inmobiliaria.. La única forma de frenarlo y convertir la vivienda en un derecho es regularlo.. La cara A y B del alquiler en el último lustro
# True Label: moderate_right
# Predicted Label: moderate_left
# ---
# Sample: Fátima Báñez invocaba a la Virgen del Rocío para solucionar la crisis. Jorge Fernández Díaz tenía un ángel llamado Marcelo. Y ahora [POLITICIAN] dice haber tenido de "asesor" al apóstol Santiago. La sociedad avanza, pero la derecha española sigue anclada en el siglo XIX.
# True Label: right
# Predicted Label: moderate_right
# ---
# Sample: Hoy, periodistas, artistas y políticos de distintos colores firmamos una carta de apoyo a la decisión de Barcelona de suspender las relaciones con Israel. Sin acciones como ésta, el apartheid en Sudáfrica no habría terminado. (2/7).
# True Label: moderate_right
# Predicted Label: moderate_left
# ---
# Sample: ¿Veis esa línea roja? 🧐. Es la inflación bajando más en España que en el resto de Europa gracias al tope del gas y a las medidas que hemos aprobado.
# True Label: left
# Predicted Label: moderate_right
# ---
# Sample: Los seguidores de QAnon asaltaron el Capitolio afirmando que existía una secta satánica de líderes demócratas. Ahora [POLITICIAN] difunde bulos conspirativos parecidos en España:.
# True Label: right
# Predicted Label: left
# ---
# Sample: No puede haber salarios indignos para los trabajadores mientras sube el IPC y los beneficios para las grandes empresas.
# True Label: left
# Predicted Label: moderate_left
# ---
# Sample: [POLITICIAN] no condena los insultos machistas del Elías Ahúja porque 'ETA' y 'escraches'. Original no ha sido.
# True Label: left
# Predicted Label: moderate_left
# ---
