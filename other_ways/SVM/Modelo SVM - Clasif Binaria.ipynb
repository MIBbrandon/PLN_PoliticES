# %% [markdown]
# **Librerías**

# %%
import numpy as np
from google.colab import drive
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report
import matplotlib.pyplot as plt
import seaborn as sb
import pandas as pd
from sklearn.model_selection import train_test_split
import nltk
from nltk.corpus import stopwords
from nltk import word_tokenize
from nltk.stem.porter import PorterStemmer
import re
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.pipeline import Pipeline
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report

# %% [markdown]
# **Cargar el dataset**

# %%
drive.mount('/content/drive')
PATH = "/content/drive/My Drive/PLN/PRÁCTICA FINAL/"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv(PATH+"politicES_phase_2_train_public.csv") 
print('dataset cargado:', df.shape)
df.head()
# Out:
# dataset cargado: (180000, 6)
#                               label  gender  profession ideology_binary  \
# 0  0008c4fab9e97623a60380ee9c88cb20  female  politician            left
# 1  0008c4fab9e97623a60380ee9c88cb20  female  politician            left
# 2  0008c4fab9e97623a60380ee9c88cb20  female  politician            left
# 3  0008c4fab9e97623a60380ee9c88cb20  female  politician            left
# 4  0008c4fab9e97623a60380ee9c88cb20  female  politician            left
#
#   ideology_multiclass                                              tweet
# 0                left  ¡Feliz 28 de febrero a todas las andaluzas y a...
# 1                left  Feliz año nuevo, feliz esperanza 💕. Querido 20...
# 2                left  🇩🇪🇪🇸 ¡Un placer encontrarme con mi homólogo al...
# 3                left  El conflicto en Ucrania ha supuesto una dramát...
# 4                left  La Academia de la Llingua Asturiana realiza un...

# %% [markdown]
# **Para la clasificación binaria me quedo solamente con los campos "tweet" y "ideology_binary"**

# %%
df_cb=df[['tweet', 'ideology_binary']].rename(columns={'tweet': 'text', 'ideology_binary': 'label'})
df_cb.head()
# Out:
#                                                 text label
# 0  ¡Feliz 28 de febrero a todas las andaluzas y a...  left
# 1  Feliz año nuevo, feliz esperanza 💕. Querido 20...  left
# 2  🇩🇪🇪🇸 ¡Un placer encontrarme con mi homólogo al...  left
# 3  El conflicto en Ucrania ha supuesto una dramát...  left
# 4  La Academia de la Llingua Asturiana realiza un...  left

# %% [markdown]
# **Crear particiones**

# %%
# quitar las siguientes 4 líneas para coger todos los datos
parte_test = 0.6
df_train, df_aux = np.split(df_cb, [int((1 - parte_test) * len(df))])
X=df_train['text'] 
y=df_train['label']

#X=df_cb['text'] 
#y=df_cb['label']

X_train, X_aux, y_train, y_aux = train_test_split(X, y, 
        test_size=0.30, random_state=42, stratify=y)

X_val, X_test, y_val, y_test = train_test_split(X_aux, y_aux, 
        test_size=0.5, random_state=42, stratify=y_aux)

print('Tamaño conjunto de entrenamiento:', len(X_train))
print('Tamaño conjunto de validación:', len(X_val))
print('Tamaño conjunto de evaluación:', len(X_test))
# Out:
# Tamaño conjunto de entrenamiento: 50400
# Tamaño conjunto de validación: 10800
# Tamaño conjunto de evaluación: 10800

# %% [markdown]
# **Distribución de las clases**

# %%
counts_train = y_train.value_counts().to_dict()
print("Distribución en training:", counts_train)
counts_val = y_val.value_counts().to_dict()
print("Distribución en validación:", counts_val)
counts_test = y_test.value_counts().to_dict()
print("Distribución en test:", counts_test)

LABELS=counts_train.keys()
print(LABELS)
# Out:
# Distribución en training: {'left': 28392, 'right': 22008}
# Distribución en validación: {'left': 6084, 'right': 4716}
# Distribución en test: {'left': 6084, 'right': 4716}
# dict_keys(['left', 'right'])

# %%
fig, (ax_train, ax_val, ax_test) = plt.subplots(1, 3, figsize=(20, 4))
fig.suptitle('Distribución de clases')
ax_train.bar(LABELS, counts_train.values(), width=0.4)
ax_train.set_title('Distribución de clases en el conjunto de entrenamiento')
ax_train.set_xlabel('Clases')
ax_train.set_ylabel('Número de Instancias')

ax_val.bar(LABELS, counts_val.values(), width=0.4)
ax_val.set_title('Distribución de clases en el conjunto de validación')
ax_val.set_xlabel('Clases')
ax_val.set_ylabel('Número de Instancias')


ax_test.bar(LABELS, counts_test.values(), width=0.4)
ax_test.set_title('Distribución de clases en el conjunto de evaluación')
ax_test.set_xlabel('Clases')
ax_test.set_ylabel('Número de Instancias')
# Out:
# Text(0, 0.5, 'Número de Instancias')

# %% [markdown]
# **Distribución del tamaño de los textos**

# %%
length_train=X_train.apply(lambda text: len(text.split()))
length_train.describe()
# Out:
# count    50400.000000
# mean        28.759921
# std         12.734339
# min          4.000000
# 25%         17.000000
# 50%         28.000000
# 75%         40.000000
# max         61.000000
# Name: text, dtype: float64

# %%
length_train.describe(percentiles=[0.25, 0.50, 0.75, 0.90, 0.95, 0.99])
# Out:
# count    50400.000000
# mean        28.759921
# std         12.734339
# min          4.000000
# 25%         17.000000
# 50%         28.000000
# 75%         40.000000
# 90%         46.000000
# 95%         48.000000
# 99%         52.000000
# max         61.000000
# Name: text, dtype: float64

# %%
length_val=X_val.apply(lambda text: len(text.split()))
length_val.describe(percentiles=[0.25, 0.50, 0.75, 0.90, 0.95, 0.99])
# Out:
# count    10800.000000
# mean        28.838519
# std         12.751401
# min          5.000000
# 25%         17.000000
# 50%         28.000000
# 75%         41.000000
# 90%         46.000000
# 95%         48.000000
# 99%         52.000000
# max         60.000000
# Name: text, dtype: float64

# %%
length_test=X_test.apply(lambda text: len(text.split()))
length_test.describe(percentiles=[0.25, 0.50, 0.75, 0.90, 0.95, 0.99])
# Out:
# count    10800.000000
# mean        28.755185
# std         12.776657
# min          4.000000
# 25%         17.000000
# 50%         28.000000
# 75%         41.000000
# 90%         46.000000
# 95%         48.000000
# 99%         52.000000
# max         62.000000
# Name: text, dtype: float64

# %%
fig, (ax_train, ax_val, ax_test) = plt.subplots(1, 3, figsize=(20, 4))
fig.suptitle('Distribución del tamaño de los textos')

ax_train.hist(length_train,  color = 'red', edgecolor = 'black',
         bins = int(600/50))
ax_train.set_title('Conjunto de entrenamiento')
ax_train.set_xlabel('Tamaño')
ax_train.set_ylabel('Número de Instancias')

ax_val.hist(length_train,  color = 'red', edgecolor = 'black',
         bins = int(200/15))
ax_val.set_title('Conjunto de validación')
ax_val.set_xlabel('Tamaño')
ax_val.set_ylabel('Número de Instancias')

ax_test.hist(length_train,  color = 'red', edgecolor = 'black',
         bins = int(300/15))
ax_test.set_title('Conjunto test')
ax_test.set_xlabel('Tamaño')
ax_test.set_ylabel('Número de Instancias')

# Add labels
plt.title('Distribución de la longitud de los textos')
plt.xlabel('Tamaño (tokens)')
plt.ylabel('Número de textos')
# Out:
# Text(0, 0.5, 'Número de textos')

# %% [markdown]
# **Representación de textos**
#
# La entrada del algoritmo de clasificación son los textos, pero estos deben ser representados como vectores de números reales. Antes de realizar esta transformación, hay que incluir algunas tareas de limpieza de los textos, eliminando palabras y símbolos que no aporten información semántica para la clasificación:

# %%
nltk.download('stopwords')
nltk.download('punkt')

stopwords_es = stopwords.words("spanish")

def clean_text(text):
    # transformar a minúscula
    text=str(text).lower()
    # tokenizar
    tokens=word_tokenize(text)
    # borrar stopwords
    tokens = [word for word in tokens if word not in stopwords_es]
    # usar los stems
    tokens = [PorterStemmer().stem(word) for word in tokens]
    # eliminamos las palabras con menos de 3 caráceres
    # ignoramos cualquier palabra que contenga un digito o un símbolo especial 
    min_length = 3
    p = re.compile('^[a-zA-Z]+$');
    filtered_tokens=[]
    for token in tokens:
        if len(token)>=min_length and p.match(token):
            filtered_tokens.append(token)
            
    return filtered_tokens
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# **tf-idf**

# %%
# entrenamos un modelo de bolsa de palabras
bow = CountVectorizer(analyzer=clean_text).fit(X_train)
# transformamos el conjunto de entrenamiento a bolsa de palabras
X_train_bow = bow.transform(X_train)
# transformamos el conjunto de evaluación a bolsa de palabras
X_test_bow=bow.transform(X_test)


# entrenamos un modelo tf-idf 
tfidf_transformer = TfidfTransformer().fit(X_train_bow)
# transformamos el conjunto de entrenamiento
X_train_tfidf = tfidf_transformer.transform(X_train_bow)
# transformamos el conjunto de entrenamiento
X_test_tfidf = tfidf_transformer.transform(X_test_bow)

print('textos han sido representados con el modelo tf-idf ')
# Out:
# textos han sido representados con el modelo tf-idf

# %%
print(X_train[1])
print(X_train_bow[1])
print(X_train_tfidf[1])
# Out:
# Feliz año nuevo, feliz esperanza 💕. Querido 2023, ¡allá vamos! .
#   (0, 4669)	1
#   (0, 14350)	1
#   (0, 16332)	1
#   (0, 19270)	1
#   (0, 19353)	1
#   (0, 19361)	2
#   (0, 19887)	1
#   (0, 23439)	1
#   (0, 24316)	1
#   (0, 26955)	1
#   (0, 28980)	1
#   (0, 29455)	1
#   (0, 30065)	1
#   (0, 30146)	1
#   (0, 30232)	1
#   (0, 30936)	1
#   (0, 34877)	1
#   (0, 35514)	1
#   (0, 38262)	1
#   (0, 38262)	0.21801148569964648
#   (0, 35514)	0.14286089544516425
#   (0, 34877)	0.20219812676236554
#   (0, 30936)	0.2419738594830434
#   (0, 30232)	0.24670882358139584
#   (0, 30146)	0.11982300417200141
#   (0, 30065)	0.2338746618868303
#   (0, 29455)	0.22504106233710056
#   (0, 28980)	0.2625158399082883
#   (0, 26955)	0.22879657743785045
#   (0, 24316)	0.15273285907172096
#   (0, 23439)	0.30049530378323613
#   (0, 19887)	0.12693662236563713
#   (0, 19361)	0.24049118139122397
#   (0, 19353)	0.29369495065483114
#   (0, 19270)	0.25740218216517907
#   (0, 16332)	0.28223980264265575
#   (0, 14350)	0.24515832166637264
#   (0, 4669)	0.22572564704071432

# %% [markdown]
# **Clasificación**

# %%
pipeline = Pipeline([
    ('bow', CountVectorizer(analyzer=clean_text)),  
    ('tf', TfidfTransformer()),  
    ('svm', SVC()), 
])

# Parámetros para el algoritmo SVM
grid_params_svm = [{'svm__kernel': ['linear', 'rbf'], 
                    'svm__C': [0.1, 1], 
                    
                    }]  

  
gs = GridSearchCV(pipeline, param_grid=grid_params_svm, 
                  scoring='accuracy', cv=3, verbose = 1)

# entrenamos el grid
gs.fit(X_train, y_train)
print('Los mejores parámetros son : %s' % gs.best_params_)
print('Mejor accuracy: %.3f' % gs.best_score_)
print(gs.best_estimator_)
# Out:
# Fitting 3 folds for each of 4 candidates, totalling 12 fits
# Los mejores parámetros son : {'svm__C': 1, 'svm__kernel': 'rbf'}
# Mejor accuracy: 0.657
# Pipeline(steps=[('bow',
#                  CountVectorizer(analyzer=<function clean_text at 0x7f5ad83224d0>)),
#                 ('tf', TfidfTransformer()), ('svm', SVC(C=1))])

# %%
predictions = gs.predict(X_test)

# %%
print( classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#         left       0.67      0.82      0.73      6084
#        right       0.67      0.47      0.55      4716
#
#     accuracy                           0.67     10800
#    macro avg       0.67      0.65      0.64     10800
# weighted avg       0.67      0.67      0.66     10800

# %%
binary_labels = ["left", "right"]
fig = plt.subplots(figsize = (5, 5))
cm_dtc1 = confusion_matrix(y_test, predictions, normalize = "true")
sb.heatmap(cm_dtc1, vmin = 0, vmax = 1, square = True, annot = True, fmt = ".2f", cbar_kws = {"shrink" : 0.5}, xticklabels = binary_labels, yticklabels = binary_labels)
plt.title("Matriz de confusión")
plt.xlabel("Valores predichos")
plt.ylabel("Valores reales")
plt.show()

# %% [markdown]
# añadir lo de noly
# preguntar a chat gpt  pq falla el modelo al clasificar

# %%
type(y_test)
#for indice, valor in y_test.items():
#    print(indice, valor)
y_test2=np.array(y_test)
# Out:
# 'left'

# %%
# Step 4: Analyze incorrect predictions

incorrect_indices = [i for i in range(len(y_test2)) if y_test2[i] != predictions[i]]
incorrect_samples = [df_cb.iloc[i]['text'] for i in incorrect_indices]
incorrect_true_labels = [y_test2[i] for i in incorrect_indices]
incorrect_predicted_labels = [predictions[i] for i in incorrect_indices]


c = 0
# Step 5: Investigate the misclassified samples
for sample, true_label, predicted_label in zip(incorrect_samples, incorrect_true_labels, incorrect_predicted_labels):
    # Analyze the misclassified sample and relevant information
    print(f'Sample: {sample}')
    print(f'True Label: {true_label}')
    print(f'Predicted Label: {predicted_label}')
    print("---")
    c = c + 1
# Out:
# Streaming output truncated to the last 5000 lines.
# Sample: @user Estábamos interviniendo y votando hasta las 23,30 horas en el Congreso. De nada
# True Label: right
# Predicted Label: left
# ---
# Sample: @user La presunción de inocencia pasa por esperar a que haya una sentencia, no pasa por dar por presunta mentirosa a una mujer que denuncia. Así que si no hay sentencia ¿por qué se asume que ella miente? Os saltan todas las costuras
# True Label: right
# Predicted Label: left
# ---
# Sample: [POLITICIAN] perdonó 400 millones a la COPE.Legaliza pozos ilegales en sequía. Baja impuestos a los ricos y tuvo 2700 millones de superávit por no saber ejecutar lo que le dio el Gobierno. [POLITICIAN] pide más dinero al Gobierno porque sabe de gestión lo que un huevo frito
# True Label: left
# Predicted Label: right
# ---
# Sample: @user ¿Ah las de Madrid te dan igual porque es [POLITICIAN] quien no las quiere investigar? Sois un meme
# True Label: right
# Predicted Label: left
# ---
# Sample: @user A ver si lo entiende, usted ni nadie puede decir que alguien miente sin que haya sentencia. Espero que ya lo haya entendido. No es tan difícil
# True Label: left
# Predicted Label: right
# ---
# Sample: @user Es al revés, cuando tienes un despacho que funciona, puedes permitirte estar un tiempo fuera y regresar, que es mi caso. Yo dono parte de mi sueldo, así que no estoy por dinero. El problema lo tiene quien no quiere prestar un servicio público, pensando solo en el dinero
# True Label: right
# Predicted Label: left
# ---
# Sample: @user Ya la tiene ¿o que te crees que ha estado pasando en este país desde que se aprobó la ley del aborto? Tomáis a la gente por idiota
# True Label: left
# Predicted Label: right
# ---
# Sample: @user Pues mejor nos quedamos con los 700, como quería el [POLITICAL_PARTY], y los precios iban a subir igual porque la guerra que afecta a toda Europa, no la hemos elegido
# True Label: right
# Predicted Label: left
# ---
# Sample: Hoy hemos acompañado a Jorge en un día muy especial. Cumple 12 años y acudía por primera vez a su colegio con un exoesqueleto que mejorará su calidad de vida. Un éxito de la investigación española. Más inversión y políticas públicas, con las personas en el centro.
# True Label: right
# Predicted Label: left
# ---
# Sample: Enhorabuena, @user  por tu victoria en estas elecciones en las que Brasil ha decidido apostar por el progreso y la esperanza. Trabajemos juntos por la justicia social, la igualdad y contra el cambio climático. Tus éxitos serán los del pueblo brasileño. ¡Parabéns, Lula!
# True Label: right
# Predicted Label: left
# ---
# Sample: Terminamos un 2022 en el que, a pesar del contexto internacional, España ha conseguido crecer y avanzar protegiendo siempre a quienes más lo necesitan.. Por un 2023 en paz, con prosperidad y justicia social. ¡Feliz año nuevo!
# True Label: right
# Predicted Label: left
# ---
# Sample: Esta mañana he conversado con el presidente @user para abordar la organización de la Cumbre de la OTAN este año en España. Reiterando, además, nuestro apoyo para potenciar la política común de Seguridad y Defensa durante este periodo de presidencia francesa de la UE.
# True Label: left
# Predicted Label: right
# ---
# Sample: Un honor asistir hoy a la reunión anual del Patronato @user  presidida por SSMM los Reyes. Enhorabuena a Gabriel Morelli, galardonado hoy con el [HASHTAG] y mi agradecimiento a todas las personas que difunden el español a través de la gran familia del Instituto Cervantes.
# True Label: left
# Predicted Label: right
# ---
# Sample: Somos el país que somos gracias a estas siglas: @user . De nuestra mano han llegado todas las conquistas sociales a España. Todas.
# True Label: right
# Predicted Label: left
# ---
# Sample: Trabajamos para reforzar nuestras relaciones bilaterales con Vietnam, un país cada vez más relevante en Asia, con grandes oportunidades para las empresas españolas en renovables, seguridad y defensa, infraestructuras o turismo. Un placer conversar con el PM Phạm Minh Chính.
# True Label: right
# Predicted Label: left
# ---
# Sample: 🌹En unos minutos estaré en el acto Municipalista en [HASHTAG] junto a @user  @user y a los compañeros y compañeras del @user .. Síguelo en directo a través de las redes sociales del @user .
# True Label: right
# Predicted Label: left
# ---
# Sample: España está comprometida con la @user y la seguridad de Europa, así lo he reiterado en mi conversación con @user . Apoyamos la soberanía e integridad territorial de Ucrania y confiamos en que la diplomacia y el diálogo sean la vía de la desescalada en esta crisis.
# True Label: left
# Predicted Label: right
# ---
# Sample: ¿Gestión financiera de hace 10 años o escudo social ante el COVID? ¿Respuesta al Prestige o a la erupción en La Palma? ¿Reforma laboral por imposición o con acuerdo?. En medio de una crisis sin precedentes, hay un Gobierno que da estabilidad y certezas. ¿Qué hay del otro lado?
# True Label: right
# Predicted Label: left
# ---
# Sample: Estamos juntos contra la violencia machista. Negarla es una forma de ejercerla. Subirla a la tribuna del Congreso es cruzar una línea intolerable.. Seguiremos adelante con convicción y determinación.. Todo mi apoyo, @user .
# True Label: left
# Predicted Label: right
# ---
# Sample: El @user y este Gobierno, ante la incertidumbre, apostamos por la esperanza y las soluciones para la gente. La inflación pasará, como estamos superando la pandemia, lo que perdura es la igualdad, la cohesión y la dignidad de las personas. Por ello trabajamos.
# True Label: left
# Predicted Label: right
# ---
# Sample: Hoy el Gobierno aprueba en [HASHTAG] una norma que pone fin a una discriminación histórica hacia las empleadas del hogar. La nueva ley garantiza su subsidio por desempleo, las equipara en derechos y protege y pone en valor el trabajo de los cuidados..
# True Label: right
# Predicted Label: left
# ---
# Sample: Estamos en un momento definitorio para la UE y las relaciones internacionales. Hay que medir las palabras, apostar por la vía diplomática y frenar la guerra y eso es parar los pies a Putin: con la unidad en Europa y la OTAN y la solidaridad hacia el pueblo ucraniano.
# True Label: left
# Predicted Label: right
# ---
# Sample: . Ni una mujer menos. Ni un asesinato machista más. Acabemos con esta lacra. Hoy se confirma el asesinato de una mujer a manos de su pareja en Ceuta. Aumentemos los recursos, lleguemos a tiempo, eduquemos en igualdad. Todo mi cariño para los familiares de esta mujer.
# True Label: right
# Predicted Label: left
# ---
# Sample: Mis deseos de una pronta recuperación, @user . Sigamos manteniendo la prudencia y la prevención frente al . Protejámonos para cuidar también de los demás.
# True Label: right
# Predicted Label: left
# ---
# Sample: Acabo de hablar con el primer ministro de Polonia, @user . Le he transmitido todo el apoyo y la solidaridad de España. Permanecemos unidos por la paz.
# True Label: right
# Predicted Label: left
# ---
# Sample: Recibo en La Moncloa a la primera ministra @user . Ambos dirigimos gobiernos socialdemócratas comprometidos en abrazar la dimensión social y feminista de la acción política. España y Finlandia seguirán reforzando la cooperación en retos clave como la digitalización.
# True Label: left
# Predicted Label: right
# ---
# Sample: He visitado las instalaciones de TSK, en el Parque Científico Tecnológico de Gijón. Esta empresa trabaja para generar soluciones más sostenibles para la industria y el sector energético. En ello avanzamos con los Fondos Europeos, en hacer un país más verde.
# True Label: right
# Predicted Label: left
# ---
# Sample: En lo que respecta a la energía, hemos debatido en este [HASHTAG] la necesidad de diversificar las fuentes de suministro e impulsar mejores interconexiones entre los mercados. Además, es importante acabar con el efecto contagio que tiene el precio del gas en el de la electricidad.
# True Label: right
# Predicted Label: left
# ---
# Sample: Mis deseos de una pronta recuperación para S.M. el Rey, Felipe VI. Espero que los síntomas sean leves y pueda recuperar pronto la normalidad. Manteniendo la prudencia frente al [HASHTAG] y siendo responsables superaremos pronto esta pandemia.
# True Label: left
# Predicted Label: right
# ---
# Sample: Desde la sentencia del Supremo se ha producido un progresivo debilitamiento de la posición de España, que tiene como estocada final la proposición de ley para acabar con el delito de sedición, cuando realmente fue una rebelión.
# True Label: left
# Predicted Label: right
# ---
# Sample: El TSJC envía a juicio a la consejera de Cultura del Govern y a dos diputados de [POLITICAL_PARTY] por el 1-O.
# True Label: right
# Predicted Label: left
# ---
# Sample: La ciencia no tiene la respuesta para esta pregunta. No existe un estudio con base científica que sostenga la existencia de un «gen asesino»
# True Label: right
# Predicted Label: left
# ---
# Sample: Centenares de seguidores de Bolsonaro asaltan el Congreso, la Presidencia y el Supremo de Brasil
# True Label: right
# Predicted Label: left
# ---
# Sample: Fuentes [POLITICAL_PARTY] muestran su preocupación por la «exhibición pública» de las discrepancias entre sus socios de [POLITICAL_PARTY] y la vicepresidenta segunda, [POLITICIAN]
# True Label: left
# Predicted Label: right
# ---
# Sample: El Gobierno no va a aceptar propuestas del [POLITICAL_PARTY] sobre el modo de elegir a los vocales del Consejo General del Poder Judicial hasta que no vuelvan a sentarse para renovar el órgano de los jueces.
# True Label: right
# Predicted Label: left
# ---
# Sample: El nombre del exministro ya había sonado con anterioridad en otros procesos previos de diálogo, pero, aun así, en la interlocución abierta, desde Moncloa se negaron los nombres, primero, y después se optó por la táctica de dar largas a la respuesta.
# True Label: right
# Predicted Label: left
# ---
# Sample: Este es mi artículo:. Aragonés, el mayordomo de [POLITICIAN] ➡ «Es un personaje gris, tan fatuo y vanidoso como escaso de atributos para el ejercicio del gobierno»
# True Label: right
# Predicted Label: left
# ---
# Sample: La hipótesis de trabajo de los asesores de [POLITICIAN] es que el batacazo del [POLITICAL_PARTY] en las municipales y autonómicas de mayo será de tal calibre que desencadenará un proceso que culminará en el relevo del liderazgo popular.
# True Label: right
# Predicted Label: left
# ---
# Sample: Ha demostrado rigor, prudencia y serenidad en unos momentos de máxima tensión. Nada fácil lo tenía el presidente del Tribunal Constitucional, Pedro González-Trevijano, ante la mayor crisis vivida en el seno del alto organismo de Garantías.
# True Label: right
# Predicted Label: left
# ---
# Sample: 400 millones de euros. Ese es el recorte que estima el Ministerio de Hacienda sobre su previsión inicial de ingresos por el nuevo impuesto a energéticas en los ejercicios 2023 y 2024 por la incorporación y aprobación de las enmiendas
# True Label: left
# Predicted Label: right
# ---
# Sample: Si bien el objetivo de esta sucesión de subidas es frenar la inflación, la subida del precio oficial del dinero tiene una derivada muy importante para miles de familias españolas: el encarecimiento de sus hipotecas variables.
# True Label: right
# Predicted Label: left
# ---
# Sample: [POLITICIAN] desautoriza a Podemos sobre la Ley del “sí es sí”: “Dejemos a los tribunales trabajar y unificar doctrina”
# True Label: left
# Predicted Label: right
# ---
# Sample: De nuevo resuenan los tambores de guerra en el seno del Gobierno de coalición y dentro del equipo económico que lidera la vicepresidenta primera, Nadia [POLITICIAN]
# True Label: right
# Predicted Label: left
# ---
# Sample: Stoltenberg pide no caer en el “chantaje nuclear” de Putin y defiende el derecho de Kyiv a seguir luchando por su territorio a pesar del intento de la ‘anexión’ rusa
# True Label: left
# Predicted Label: right
# ---
# Sample: Zelenski necesita carros de combate occidentales para contrarrestar la contraofensiva que Rusia prepara en las regiones orientales.
# True Label: right
# Predicted Label: left
# ---
# Sample: Hoy celebramos la VI edición de los , un reconocimiento a uno de los sectores más imprescindibles para el desarrollo de nuestro país
# True Label: left
# Predicted Label: right
# ---
# Sample: Es lamentable que el gurú Pablo Iglesias y sus acólitas pretendan erigirse en los únicos adalides de la defensa de las mujeres y politicen esta cuestión de una forma tan grosera. Es una ofensa para los partidos, tanto en la izquierda como en la derecha, que protagonizaron avances
# True Label: right
# Predicted Label: left
# ---
# Sample: Con el apoyo de Bélgica al plan de autonomía marroquí para el Sáhara, ya son 11 los países europeos, incluidos 10 de la UE, que han manifestado respaldo a dicho plan. .
# True Label: left
# Predicted Label: right
# ---
# Sample: Al menos dos muertos en Polonia tras la caída de dos misiles rusos cerca de la frontera con Ucrania. Sigue el directo aquí:
# True Label: right
# Predicted Label: left
# ---
# Sample: Feijoo, ha reprochado hoy al Gobierno que retrase la aplicación de las medidas económicas para el próximo ejercicio en un contexto de creciente endeudamiento y menor crecimiento
# True Label: right
# Predicted Label: left
# ---
# Sample: [POLITICIAN] mostró su confianza en ganar las próximas elecciones “lo tengo claro”, y volvió a pedir un adelanto electoral. “Me preocupa mucho qué pueden seguir haciendo hasta las elecciones generales” al considerar que, en el Ejecutivo, “no hay escrúpulos”
# True Label: right
# Predicted Label: left
# ---
# Sample: Aquí el [HASHTAG] de anoche en el Alcázar. En cada función un poquito de material en directo, escrito esa semana para vosotros. Una vez que sale no lo vuelvo a hacer.
# True Label: left
# Predicted Label: right
# ---
# Sample: Puto @user cualquier día le suelto una hostia. Por envidia pura.
# True Label: right
# Predicted Label: left
# ---
# Sample: Anoche fui a ver . @user es un sueño de Willy Wonka, el casting es fantástico y la producción impecable. Muy recomendable. Venga, ya podéis reíros de mi outfit y mi monsesuarismo.
# True Label: right
# Predicted Label: left
# ---
# Sample: @user Bueno, hay pelis porno con mejores diálogos… y tú lo sabes 😉
# True Label: right
# Predicted Label: left
# ---
# Sample: @user Estoy rodando casi a diario y están siendo jornadas un poco largas de frío y lluvia. Prefiero esperar a encontrarme un poco mejor. Mil gracias a tod@s por el apoyo, es impresionante y abrumador todo lo que hacen ❤️.
# True Label: right
# Predicted Label: left
# ---
# Sample: Quiero agradecer públicamente a mis amigo @user y @user que no hayan venido a hacer daño después del bochorno celeste en Puzela anoche.
# True Label: right
# Predicted Label: left
# ---
# Sample: Le doy la bienvenida a [POLITICIAN] en su vuelta y aparece la gente con corazón. Una vez terminada la quimioterapia ni un minuto de paz. Pero la bandera de Ucrania que no falte.
# True Label: right
# Predicted Label: left
# ---
# Sample: El más listo de la clase una vez más. .
# True Label: right
# Predicted Label: left
# ---
# Sample: Lo estamos dando, lo estamos regalando. 2023 el año de las ofertas. Ojalá fuese año electoral siempre.
# True Label: right
# Predicted Label: left
# ---
# Sample: En Santo Domingo surgió el debate de porros o huérfanos.
# True Label: right
# Predicted Label: left
# ---
# Sample: Esta tarde en @user le pone el cascabel al gato y hace la pregunta que ronda España entera.
# True Label: left
# Predicted Label: right
# ---
# Sample: La premisa es llevar la comedia de sala a las tablas. Así que, aunque vengas al teatro, huela a teatro y se mueva como un teatro, en «LAGO» no estás en un teatro.. Estás en un Comedy Club. 👇
# True Label: left
# Predicted Label: right
# ---
# Sample: Perdona pero si de algo sé es de Holanda.
# True Label: right
# Predicted Label: left
# ---
# Sample: La función de [HASHTAG] de mañana sábado en el Teatro Alcázar apunta a llenazo. Sois más de 400 los que ya tenéis vuestro ticket. Mi manera de devolveros la confianza será estrenar dos rutinas. Fútbol femenino y noche de Jagüolin.
# True Label: left
# Predicted Label: right
# ---
# Sample: Si pero ahora ya es considerado “programa de culto”. Ojo ahí.
# True Label: left
# Predicted Label: right
# ---
# Sample: Never forget el día en que me di cuenta que sin barba soy Carmen Borrego.
# True Label: right
# Predicted Label: left
# ---
# Sample: Ni compasión ni pena. AMOR. Seguimos trabajando para que la infancia de los niños dominicanos sea un poquito mejor cada día.
# True Label: right
# Predicted Label: left
# ---
# Sample: Este sábado GRAN ESTRENO de mi . Me he agenciado un garito en el centro y cada semana saco toda la comedia que llevo dentro.. Esta será especial por la gran cantidad de amigos y compañeros que pasarán la noche conmigo.. Qué nervios. Te vienes?
# True Label: right
# Predicted Label: left
# ---
# Sample: Bueno, pues parece que el próximo 7 de noviembre será mi último día en esta armoniosa red social. .
# True Label: right
# Predicted Label: left
# ---
# Sample: Anoche @user recibió un merecido reconocimiento a su labor humanitaria en la CasaBlanca, de manos del Presidente. Luego un concierto de 45 minutos. Aquí os dejo este regalo.
# True Label: right
# Predicted Label: left
# ---
# Sample: @user No trabajo ahí desde hace casi 9 meses. Estas reclamaciones son en otra ventanilla.
# True Label: right
# Predicted Label: left
# ---
# Sample: Aquí mi conversación con Alberto [POLITICIAN] en @user Gracias por el cariño. .
# True Label: left
# Predicted Label: right
# ---
# Sample: Ayer me crucé con @user y la frase que me salió fue “enhorabuena por tener a @user en tu vida”.. Lo peor de todo es que me salió de corazón, sin sarcasmo.. Anda que como le caiga mal…
# True Label: right
# Predicted Label: left
# ---
# Sample: Encuesta seria.. Este sábado, a mi estreno en el Alcázar, parece que va a acudir el sujeto pasivo de una de mis bromas más locas y divertidas (no es la Infanta). La pregunta es clara. ¿Mantenemos el texto?
# True Label: right
# Predicted Label: left
# ---
# Sample: Veremos qué tal el nuevo entrenador. Gracias por los servicios prestados, Coudet.
# True Label: right
# Predicted Label: left
# ---
# Sample: Menuda primera semana de Antena 3 y menuda primera semana de Telecinco. Se presenta caliente la temporada.
# True Label: right
# Predicted Label: left
# ---
# Sample: @user Es que ya está verificada. Si ahora cambian las reglas del juego bye bye
# True Label: left
# Predicted Label: right
# ---
# Sample: @user Voy a tope. Mi idea es tú con el smoking de @user y yo con el vestido de @user . Pero lo vamos hablando. Que tenemos un par de meses por delante.
# True Label: left
# Predicted Label: right
# ---
# Sample: Never forget cuando de chaval caí en la droga y le saqué tarjeta amarilla a @user
# True Label: left
# Predicted Label: right
# ---
# Sample: Llevo 20 minutos de [HASHTAG] y estoy agotado. Mucho ejercicio cinematográfico para un zote como yo.
# True Label: left
# Predicted Label: right
# ---
# Sample: Ojo a esto que lo dice @user Un ser humano maravilloso que se puso la “chaqueta buena” para venir a verme. (Te echo de menos y me alegró un huevo verte, se me estaba olvidando el cariño que te tengo)
# True Label: left
# Predicted Label: right
# ---
# Sample: Aquí @user haciendo uso del [HASHTAG] que es cuando se puede grabar, abrir directo… lo que quieras. Cada fin de semana una función distinta en el Alcázar.
# True Label: right
# Predicted Label: left
# ---
# Sample: Te lo agradezco porque a fin de cuentas ¿quien sabe qué pasará?
# True Label: left
# Predicted Label: right
# ---
# Sample: Laxalt lo deja claro... luchó pero perdió. Trump sin embargo sigue con sus teorías de negación de la realidad... le robaron la elecciones. Es solo el inicio del terremoto en el GOP
# True Label: right
# Predicted Label: left
# ---
# Sample: El negocio de banca de consumo de JP Morgan Chase le generó unos ingresos de 15.840 millones de dólares, casi un 30% más que hace un año. Esta cifra de negocio le generó un beneficio de 4.540 millones, un 10% más
# True Label: right
# Predicted Label: left
# ---
# Sample: Lamborghini presenta el Huracán Sterrato. Es difícil imaginar que un deportivo con un motor V10 de 5,2 litros capaz de generar 610 caballos pueda competir en un rally, pero bueno. El anuncio, por cierto, es malísmo
# True Label: right
# Predicted Label: left
# ---
# Sample: Woz is in the house [HASHTAG] @user en el Ateneo ... voy a disfrutar a @user más que el pavo de Acción de Gracias
# True Label: right
# Predicted Label: left
# ---
# Sample: @user Qué tal, Mario. Gracias por el comentario. Si me ves por la calle, me paras sin problema e improvisamos algo sobre la marcha. Un café se va a quedar corto, me temo
# True Label: right
# Predicted Label: left
# ---
# Sample: No recuerdo un terremoto de esta magnitud en Oriente Medio en mucho tiempo. Los fallecidos se acercan ya los 300
# True Label: right
# Predicted Label: left
# ---
# Sample: @user La inflación es muy difícil de predecir. Pero en el caso de la Fed, le llega información constante de los bancos regionales, que son los que toman el pulso de la economía en tiempo real. Es más peligroso que la inflación se incrustre porque frena la economía más que los tipos
# True Label: right
# Predicted Label: left
# ---
# Sample: Xi abre el Congreso del Partido Comunista chino con un discurso de casi dos horas en el que dejó muyr claro que no va a abandonar el recurso al uso de la fuerza en Taiwán para la reunificación
# True Label: right
# Predicted Label: left
# ---
# Sample: Centeno cree que la inflación hará cima este trimestre... es lo que decían en primavera que pasaría en verano. Esta vez acertarán porque a partir de ahora la comparativa es con el dato del año precedente
# True Label: left
# Predicted Label: right
# ---
# Sample: El presidente de la Fed insiste que las condiciones restrictivas de la política monetaria seguirán durante un tiempo pese a que la economía se debilita. El mercado laboral, señala, es robusto
# True Label: right
# Predicted Label: left
# ---
# Sample: Powell.- "Hay que evitar declarar victoria de una manera prematura". El proceso de desinflación está en marcha en el sector de bienes pero en la Fed están ahora muy pendientes de la inflación en el sector servicios, excluyendo el inmobiliario
# True Label: right
# Predicted Label: left
# ---
# Sample: Y mientras Alemania y EE UU se enzarzan con los tanques, Zelensky pide armamento que le permite alcanzar objetivos más allá de la línea de frente y así reclamar territorios ocupados como Crimea. El Pentágono dejó caer a principios de la semana que entiende la posición de Kiev
# True Label: left
# Predicted Label: right
# ---
# Sample: @user Es una monarquía parlamentaria muy particular. Técnicamente el mandato es al partido y los diputados eligen al presidente con la mayoría... por ahí se escapan
# True Label: right
# Predicted Label: left
# ---
# Sample: El beneficio combinado de Chevron, ExxonMobil, BP, Shell y Total Energies se estima rondará los 200.000 millones de dólares en 2022, un 50% más
# True Label: right
# Predicted Label: left
# ---
# Sample: @user ahora lo entiendo todo... no hay nada mejor para filtrar que la burocracia
# True Label: right
# Predicted Label: left
# ---
# Sample: Y me parecía caro los cuatro pavos que valía la bolsa de papas fritas en el supermercado en Nueva York...
# True Label: left
# Predicted Label: right
# ---
# Sample: Mike Pence también tiene documentos clasificados en su casa de cuando era vicepresidente con Donald Trump
# True Label: left
# Predicted Label: right
# ---
# Sample: Biden dice que DeSantis es la encarnación de Trump
# True Label: right
# Predicted Label: left
# ---
# Sample: Hay varios miembros del BCE hablando. Todos van en el mismo sentido. Los tipos deben subir más e insisten para jutificar una política restrictiva que hay factores del lado de la demanda que alimentan el alza de precios. Mantener la inflación alta, concluyen, tiene un coste mayor
# True Label: right
# Predicted Label: left
# ---
# Sample: Israel autoriza a los miemrbos de la OTAN entregar equipamiento militar defensivo a Ucrania que intengren componentes que desarrollan su complejo militar
# True Label: right
# Predicted Label: left
# ---
# Sample: El NOTAM es un sistema crítico para regular el tráfico aéreo en los EE UU. El problema informático afecta a las operaciones en todos los aeropuertos del sistema nacional, justo cuando amanece en la costa Este
# True Label: right
# Predicted Label: left
# ---
# Sample: Un jurado ordena a Alex Jones de Infowars compensar con 965 millones de dólares a ocho familiares de víctimas de Sandy Hook, por decir en su programa de radio que la matanza en la guardería fue un montaje. Es una de las tres causas a las que se enfrenta por difamación
# True Label: right
# Predicted Label: left
# ---
# Sample: @user Vamos a ver. Para empezar no es una vacuna. Era y es el mejor tratamiento para proteger a la población. Por tanto, no previene la infección. Y no hay que investigar nada, sólo había que seguir los debates previos del panel de expertos de la FDA y leer los informes. Eran públicos
# True Label: left
# Predicted Label: right
# ---
# Sample: Xi pide a Biden que traslade sus compromisos en acciones concretas, en lugar de decir una cosa y hacer otra. En lo único que están de acuerdo es en seguir manteniendo el canal de comunicación abierto para evitar una confrontación. Blinken visitará Pekín próximamente
# True Label: left
# Predicted Label: right
# ---
# Sample: @user O con mi nombre trucao (y del Sevilla)
# True Label: left
# Predicted Label: right
# ---
# Sample: La necesidad de una salida negociada a la guerra de Ucrania gana cuerpo con la retirada rusa de Kherson y los comentarios contínuos de Biden en plena fatiga de Occidente. Como dice Borrell, todo depende de Ucrania. Lo hablamos en @user
# True Label: right
# Predicted Label: left
# ---
# Sample: Macron no excluye el envío de cazas a Ucrania
# True Label: right
# Predicted Label: left
# ---
# Sample: Scholz se dipone a anunciar la transferencia a Ucrania de tanques Leopard 2A6, según la prensa alemana. Polonia, Noruega, Dinamarca y Finlandia consideran mandar unidades. Se les sumarían los Abrams de EE UU y los Leclerc franceses, combinados con los Challenger británicos
# True Label: right
# Predicted Label: left
# ---
# Sample: Las protestas en China puso en apuros a Twitter, que con el recorte de plantilla y la fuga de expertos tuvo dificultad para lidiar con miles de cuentas automatizadas que despertaron de un largo letargo colgando información que nada tenía que ver con la movilización
# True Label: right
# Predicted Label: left
# ---
# Sample: Elon pierde el título de hombre más rico del mundo por el desplome en el valor de Tesla
# True Label: right
# Predicted Label: left
# ---
# Sample: Felicidades por el reconocimiento @user y todo el equipo de @user
# True Label: right
# Predicted Label: left
# ---
# Sample: Capturado el hijo de El Chapo Guzmán. EE UU daba una recompensa de 5 millones de dólares por información que llevara a su arresto
# True Label: right
# Predicted Label: left
# ---
# Sample: El Kremlin señala directamente a Londres por la explosión del Nord Stream y advierte que está considerando acciones al respecto. Los jaqueo del móvil de Liz Truss no es ninguna un broma. En cuanto a la reparación, no hay decisión aún
# True Label: right
# Predicted Label: left
# ---
# Sample: La Reserva Federal de EEUU sube tipos en 50 puntos básicos y cierra el año con siete incrementos
# True Label: right
# Predicted Label: left
# ---
# Sample: @user gracias por el apoyo... lo de grande, lo dejo en alto y con flequillo
# True Label: right
# Predicted Label: left
# ---
# Sample: La tasa de paro en EE UU sube dos décimas, al 3,7%. La creación de empleo mantiene sin embargo el ritmo al registrar 261.000 ocupados, mejor de lo esperado. La tasa de participación laboral se mantienen en el 62,2%
# True Label: left
# Predicted Label: right
# ---
# Sample: El ministro francés de Interior ya habla de "consecuencias extremadamente severas" en la relaciones entre los dos países fundadores de la Unión Europea
# True Label: right
# Predicted Label: left
# ---
# Sample: @user Pues imagina cuando te llevas la copa a la boca y sube por la nariz
# True Label: left
# Predicted Label: right
# ---
# Sample: Hay 67 países en el mundo que penalizan la homosexualidad, de entre los cuales once contemplan o aplican la pena capital. El Papa lo considera injusto, "no es un crimen".
# True Label: right
# Predicted Label: left
# ---
# Sample: [POLITICIAN] recibe un sueldo récord de Murdoch y ha cobrado ya cerca de 4 millones como asesor del magnate
# True Label: left
# Predicted Label: right
# ---
# Sample: El G7 entra en la batalla del petróleo ruso con un tope al precio del barril
# True Label: left
# Predicted Label: right
# ---
# Sample: La inflación cae al 5,8% en diciembre, pero los alimentos se disparan
# True Label: right
# Predicted Label: left
# ---
# Sample: El [POLITICAL_PARTY] atasca la renovación de los dos consejeros con el mandato caducado del Banco de España
# True Label: left
# Predicted Label: right
# ---
# Sample: Bruselas apuesta ahora por abandonar el tratado que blinda las inversiones en energías fósiles
# True Label: right
# Predicted Label: left
# ---
# Sample: La negociación sobre pensiones no arranca a falta de la propuesta del Gobierno
# True Label: right
# Predicted Label: left
# ---
# Sample: Pobreza energética: se dispara el porcentaje de hogares que no pueden tener su casa a temperatura adecuada
# True Label: right
# Predicted Label: left
# ---
# Sample: La economía de España no se ahoga en la cuesta de enero
# True Label: left
# Predicted Label: right
# ---
# Sample: La gran negociación del comercio: más de 300.000 trabajadores están pendientes de saber su salario y condiciones laborales
# True Label: right
# Predicted Label: left
# ---
# Sample: El Banco de España pide a la banca que aumente las provisiones ante la amenaza de evolución adversa de la economía
# True Label: right
# Predicted Label: left
# ---
# Sample: La Inspección de Trabajo sanciona al consorcio público Instituto Europeo del Mediterráneo (@user ) por emplear a falsos becarios con contratos irregulares
# True Label: right
# Predicted Label: left
# ---
# Sample: Dia y Mercadona, los supermercados que más han subido el precio de la cesta de la compra, según la OCU
# True Label: right
# Predicted Label: left
# ---
# Sample: Inditex vende su negocio en Rusia, pero abre la posibilidad a volver
# True Label: left
# Predicted Label: right
# ---
# Sample: La Audiencia Nacional tumba una vía de despido fácil por "bajo rendimiento" en contratos de teleoperadoras
# True Label: right
# Predicted Label: left
# ---
# Sample: China resetea su economía con un intervencionismo al dictado de Xi Jinping
# True Label: left
# Predicted Label: right
# ---
# Sample: Endesa rebaja a 250 millones el impacto del nuevo impuesto y eleva un 28% su previsión de beneficio ordinario en 2022
# True Label: right
# Predicted Label: left
# ---
# Sample: ¿Tiene la economía un factor emocional determinante? De crisis, bancos centrales y subidas de tipos de interés. 👇🏼
# True Label: left
# Predicted Label: right
# ---
# Sample: Contra la violencia de género: prestar atención a la realidad y no enmascararla con ideologías ni ficciones. 👇🏼
# True Label: right
# Predicted Label: left
# ---
# Sample: Neoeuropeísmo español. O cómo la guerra de Ucrania reinterpreta el dolor al que ya aludió Unamuno. 👇🏼
# True Label: right
# Predicted Label: left
# ---
# Sample: Cuatro imágenes, un reinado y todo el siglo XX.
# True Label: left
# Predicted Label: right
# ---
# Sample: En días de propuestas desenfrenadas y excéntricas, como condenar la malversación en función del destino que se dé al dinero público, ahí va otra más: todos daneses. 👇🏼
# True Label: right
# Predicted Label: left
# ---
# Sample: El pensamiento pop, sus derivadas políticas y la cuota de responsabilidad ciudadana. Entre Churchill y Warhol. 👇🏼
# True Label: right
# Predicted Label: left
# ---
# Sample: Muchas teorías, las que caben de Hobbes a Rousseau, y una solución para frenar las agresiones sexuales en grupo: educación. Más y mejor.👇🏼
# True Label: right
# Predicted Label: left
# ---
# Sample: Comentarios jocosos sobre la comisión de un delito, un entrenador cuestionado y un equipo de fútbol femenino. ¿Dónde fijamos los límites? 👇🏼
# True Label: left
# Predicted Label: right
# ---
# Sample: Siete meses desde que Occidente salió de Afganistán. Las niñas siguen allí y quieren estudiar.
# True Label: left
# Predicted Label: right
# ---
# Sample: Siempre Javier Marías y los consejos de su espía Jaime o Jacobo o Jacques Deza. 👇🏼
# True Label: right
# Predicted Label: left
# ---
# Sample: Sin un cambio de paradigma que elimine extremismos y radicalismos, nos instalamos incómodamente en el cuento de nunca acabar. 👇🏼
# True Label: right
# Predicted Label: left
# ---
# Sample: Decía Mark Twain que la historia no se repite, pero rima. Y, con esa métrica, cada generación debe encontrar su propia armonía para aportar soluciones. 👇🏼
# True Label: left
# Predicted Label: right
# ---
# Sample: ¿Cómo se hace frente al absurdo populista que nos corroe? 👇🏼
# True Label: right
# Predicted Label: left
# ---
# Sample: Los poderes del Estado mantienen la tensión institucional en un choque sin fin: como en una especie de relación abierta mal avenida. 👇🏼
# True Label: right
# Predicted Label: left
# ---
# Sample: Conviene no abusar de medidas excepcionales propias de tiempos bélicos. Y, sobre todo, conviene no equivocarse en la elección de las palabras. 👇🏼
# True Label: right
# Predicted Label: left
# ---
# Sample: Todos los errores del “caso Alves”: lo que va del “yo sí te creo” a la justicia ejemplarizante. 👇🏼
# True Label: right
# Predicted Label: left
# ---
# Sample: Política trampantojo: el rasgo de nuestro tiempo y la gran pregunta por responder. 👇🏼
# True Label: left
# Predicted Label: right
# ---
# Sample: A estas alturas del verano, con el nuevo curso acechando, a muchos les da por ordenar. Un armario, el trastero, la biblioteca o qué se yo, quizá, su vida. 👇🏼
# True Label: right
# Predicted Label: left
# ---
# Sample: El último giro de la nueva censura llega al Congreso: si no lo reflejamos en el diario de sesiones, las generaciones futuras no sabrán quiénes éramos. 👇🏼
# True Label: right
# Predicted Label: left
# ---
# Sample: Sobre los riesgos de distorsionar el pasado a través de un juego de espejos. 👇🏼
# True Label: left
# Predicted Label: right
# ---
# Sample: Dudas, medidas contradictorias y alguna sesión en el gimnasio. ¿Estamos preparados para vivir en “Absurdistán”? 👇🏼
# True Label: left
# Predicted Label: right
# ---
# Sample: La Justicia, el estancamiento de algunos de sus problemas y los principios de Ulpiano. 👇🏼
# True Label: right
# Predicted Label: left
# ---
# Sample: Los riesgos de intentar regir la política con los modos del fanatismo futbolero. 👇🏼
# True Label: right
# Predicted Label: left
# ---
# Sample: Preocupaciones del siglo XXI: de la subida de los tipos de interés al botón nuclear. 👇🏼
# True Label: right
# Predicted Label: left
# ---
# Sample: Un poco más del “solo sí es sí” y “poner el consentimiento en el centro”. ¿Por qué una campaña publicitaria no puede convertirse (sin filtro previo) en norma penal? 👇🏼
# True Label: left
# Predicted Label: right
# ---
# Sample: Qatar convertido en el mejor escaparate de los derechos humanos: el Mundial y su paradoja. 👇🏼
# True Label: left
# Predicted Label: right
# ---
# Sample: De los augurios de Houellebecq y el desmantelamiento del sistema de partidos: ficciones políticas que se vuelven reales. ¿Cómo estaremos dentro de cinco años? 👇🏼
# True Label: left
# Predicted Label: right
# ---
# Sample: Un poco de costumbrismo tecnológico (y ligero) con gasolinera de fondo. Ya vendrá septiembre para hablar de los precios. 👇🏼
# True Label: right
# Predicted Label: left
# ---
# Sample: Europa se enfrenta, de nuevo, a un golpe de esos que, según nos enseñó Monnet, la construyen. Aunque antes sea necesario encarar un otoño adverso. 👇🏼
# True Label: right
# Predicted Label: left
# ---
# Sample: El coraje cívico de Rushdie para enfrentarse al fanatismo: vivir, como en homenaje a Chejov. 👇🏼
# True Label: right
# Predicted Label: left
# ---
# Sample: 🇮🇨 La Ventana del Nublo y el Roque Nublo (Gran Canaria) con el Teide (Tenerife) al fondo al atardecer y cubiertos por una densa niebla.
# True Label: right
# Predicted Label: left
# ---
# Sample: Artículo negacionista y retardista de principio a fin. La bibliografía está repleta de los clásicos perfiles vende humos. El texto es del geólogo Enrique Ortega Gironés. Se publicó en la web y el Colegio Oficial de Geólogos lo republicó en su web.
# True Label: right
# Predicted Label: left
# ---
# Sample: Me he pillado un '3x1' de segunda mano. ¿Recomendaciones de negocios en la isla que vendan carretes y revelen?.
# True Label: right
# Predicted Label: left
# ---
# Sample: Por supuesto, pude inmortalizar la clásica estampa de turistas invadiendo la reserva natural 💜.
# True Label: left
# Predicted Label: right
# ---
# Sample: @user Buenas. Soy el productor de Antena 6. ¿Las imágenes son suyas? ¿Podemos usarlas para nuestro informativo citándole como autor del vídeo? Gracias.
# True Label: right
# Predicted Label: left
# ---
# Sample: Y algo que me ha hecho mucha ilusión y que no esperaba: que me incluya entre sus agradecimientos 😊. Lo malo es que también está @user 🤣.
# True Label: left
# Predicted Label: right
# ---
# Sample: @user Las Dunas se conciben (tanto desde la administración como las personas) como un bien turístico y económico y no como un ecosistema natural (y frágil). Lo dicho: educación ambiental y más seguridad para empezar.
# True Label: left
# Predicted Label: right
# ---
# Sample: Sacar adelante el crowdfunding significa tener más temazos como este de @user : .
# True Label: right
# Predicted Label: left
# ---
# Sample: @user ¡Gracias, Abel! No recuerdo que haya habido problemas con lluvias fuertes pasadas ni en la calle ni el garaje, pero uno no vive todos los días una tormenta tropical jaja
# True Label: right
# Predicted Label: left
# ---
# Sample: En 2020, con motivo del lanzamiento de su fundación, hablé con @user . Me encantaría poder volver a charlar con él y ver cómo lo ve todo dos años después (y en qué ha cambiado él desde el punto de vista de la acción climática).
# True Label: right
# Predicted Label: left
# ---
# Sample: Que valoro mucho el tiempo, esfuerzo y sacrificio que hacen, de verdad. Pero al menos que valga la pena. Haced lo mismo en la casa del político de turno o en la del CEO de una petrolera o en las instalaciones de una macrogranja. Ahí sí tiene sentido y tendrá un gran respaldo.
# True Label: left
# Predicted Label: right
# ---
# Sample: A esta gente y sus discursos hay que confrontarlos siempre.
# True Label: left
# Predicted Label: right
# ---
# Sample: Pensando en mandarle un DM por si quiere poner pasta en el crowdfunding. Con una aportación suya lo dejamos hecho esta tarde.
# True Label: right
# Predicted Label: left
# ---
# Sample: Este párrafo es un despropósito. "Mayor sosteniblidad", dice. El gas FÓSIL está formado en su mayoría por metano, el segundo gas de efecto invernadero responsable del calentamiento del planeta. Tiene incluso un potencial de calentamiento muy superior al dióxido de carbono (CO2).
# True Label: right
# Predicted Label: left
# ---
# Sample: @user Como se puede leer en la memoria-resultados de MasDunas de este año, hace falta mucho más. Sobre todo más agentes de medio ambiente (rara vez los veo en la zona del mirador) y más educación ambiental. Y más presupuesto.
# True Label: left
# Predicted Label: right
# ---
# Sample: El Roque Nublo y las Dunas de Maspalomas son, posiblemente, los dos mayores emblemas naturales de Gran Canaria. A pesar de la distancia y altitud que los separa, ¿es posible tener en una misma imagen a los dos a la vez? SÍ 😊.
# True Label: right
# Predicted Label: left
# ---
# Sample: @user Lo peor es que con Tik Tok no me lo esperaba. Pensaba que sería rollo más instragram, que es la que veo que tiene menos malos rollos en comentarios.
# True Label: right
# Predicted Label: left
# ---
# Sample: 🚨 Eventos extremos 2022 y su relación con el cambio climático 🚨. - Sequía hemisferio norte: 20 veces más probable por el cambio climático. - Ola de calor Reino Unido (+40 ºC por 1ª vez): 10 veces más probable por el CC. - Inundaciones Pakistán: lluvias 50% más intensas por el CC
# True Label: right
# Predicted Label: left
# ---
# Sample: No se está hablando mucho de este tema aún y creo que es bastante preocupante para el estudio de la ciencia del clima:
# True Label: right
# Predicted Label: left
# ---
# Sample: Lo siento, pero no pienso ayudar a este gobierno a transformar el debate político en una discusión sobre los pezones de nosequien. Yo lo que quiero saber es quién va a pagar con su dimisión el inmenso daño a las mujeres provocado por la suelta de violadores.
# True Label: right
# Predicted Label: left
# ---
# Sample: ¿Qué hace que los jóvenes musulmanes EUROPEOS se radicalicen contra Occidente? ¿Las prédicas de unas mezquitas a las que esos jóvenes generalmente no acuden? ¿O el que los políticos EUROPEOS estén todo el día lanzando el mensaje de que la civilización occidental es una mierda?🤔
# True Label: right
# Predicted Label: left
# ---
# Sample: Ningún miembro del gobierno asiste al funeral del sacristán asesinado en Algeciras. Debe de ser que no quieren molestar a Mohamed VI.
# True Label: left
# Predicted Label: right
# ---
# Sample: 1) No debería ser necesario explicar esta obviedad científica, pero el feto no es parte del cuerpo de su madre. Como el huevo no es parte de la gallina. Que algo se origine en el interior de tu cuerpo no implica que sea parte de tu cuerpo.
# True Label: right
# Predicted Label: left
# ---
# Sample: 120.000 pavos al año cobra esta mujer. Eso son 120.000 buenas razones para no dimitir. ¿Qué son, al lado de eso, unos cientos de delincuentes sexuales beneficiados?. ¿Qué importa el daño causado a las mujeres al lado de 120.000 napos, que nunca había uno soñado llegar a cobrar?
# True Label: right
# Predicted Label: left
# ---
# Sample: @user No pueden perder lo que no era suyo: el senado ya lo tenían los demócratas
# True Label: right
# Predicted Label: left
# ---
# Sample: Ah, ¿pero entonces hay algo que la policía local y los mozos de escuadra DEBEN hacer y no hacen? ¿Entonces resulta que sí que existe un problema de okupación? ¿Pero no era un invento de la ultraderecha?🤔
# True Label: right
# Predicted Label: left
# ---
# Sample: Es una elección lógica. Es lo que más le gusta en el mundo y lo que mejor sabe hacer: tocar las bolas.
# True Label: left
# Predicted Label: right
# ---
# Sample: @user Tres años después de eso, resulta que Tuvalu no solo no desaparecía, sino que había crecido en los últimos 60 años:.
# True Label: right
# Predicted Label: left
# ---
# Sample: @user Me vale. Lástima que no haya de Neptuno y más atrás a la misma hora.
# True Label: right
# Predicted Label: left
# ---
# Sample: Por cierto, la conocida frase "Españoles, la patria está en peligro; acudid a salvarla" es completamente inventada. No figura en el bando que los alcaldes de Móstoles firmaron y que prendió la mecha de la sublevación contra el francés.
# True Label: right
# Predicted Label: left
# ---
# Sample: Ayer hubo DOS ataques: el de Algeciras y otro en Alemania, con dos asesinados a cuchilladas en un tren; hay, además, otros siete heridos. ¿Dos lobos solitarios que deciden, casualmente, atentar con pocas horas de diferencia? ¿O hay organizaciones diciendo: "Ahora"?
# True Label: right
# Predicted Label: left
# ---
# Sample: @user Yo soy absolutamente feliz cuando los progres prueban de su propia medicina, equidistante caballero.
# True Label: left
# Predicted Label: right
# ---
# Sample: A exhibir símbolos genocidas a otra parte. En mi TL no admito basura. Block
# True Label: left
# Predicted Label: right
# ---
# Sample: @user Hombre, dejémoslo en simultáneo. Esas cosas se pactan en las pertinentes conversaciones
# True Label: right
# Predicted Label: left
# ---
# Sample: La policía iraní deteniendo a niños en los colegios, mientras las protestan inician su cuarta semana,.
# True Label: left
# Predicted Label: right
# ---
# Sample: Pues hombre, si eres presidente de Brasil y no eres capaz de garantizar la limpieza de las elecciones, entonces te mereces que echen. Aunque solo sea por idiota, ¿no le parece? Ese discurso flojea un poco.
# True Label: right
# Predicted Label: left
# ---
# Sample: No vean Vds. cuánto lloro al pensar que [POLITICIAN] no encuentra lista electoral en la que meterse😢. Marchando hemeroteca👇
# True Label: left
# Predicted Label: right
# ---
# Sample: No había visto esto de la candidata del [POLITICAL_PARTY] a la Junta de Extremadura hablando del aborto como un "derecho". Qué triste. Pero bueno, es lo que hay. Pese a ella y pese a todo, el derecho a la vida se terminará imponiendo.
# True Label: left
# Predicted Label: right
# ---
# Sample: Misterios de la tecnología. A mí lo que me pasa es que mi número de seguidores parece crecer más rápido ahora. Será que Elon Musk nos tiene cariño.🤷‍♂️
# True Label: right
# Predicted Label: left
# ---
# Sample: Otro salivando. Fuera, bicho, que me pones el TL lleno de babazas.
# True Label: right
# Predicted Label: left
# ---
# Sample: 6) Y en ese sentido es importante (y alentador) que la concentración en Colón (y en muchas otras provincias) fuera un éxito. PERO NO ES LO FUNDAMENTAL. Aunque hubiera sido un fracaso o un simple éxito a medias, la concentración era igualmente ineludible.
# True Label: right
# Predicted Label: left
# ---
# Sample: @user ¿De Argentina? Porque de Argentina sí parece que opina.
# True Label: left
# Predicted Label: right
# ---
# Sample: @user Pero eso es estimación. Me ciño a los datos constatados
# True Label: right
# Predicted Label: left
# ---
# Sample: Así es: hay que contribuir a la defensa común. Pero, ¿qué descuento nos aplican porque Ceuta y Melilla no estén protegidas?. Primera ministra lituana: "España debe subir gasto militar. No vale estar en la OTAN para que te rescaten sin hacer tu contribución"
# True Label: right
# Predicted Label: left
# ---
# Sample: El nuevo gobierno sueco, igual que el italiano, incrementará su ayuda militar a Ucrania. ¿Pero no decía [POLITICIAN] que Putin es de ultraderecha? 🤔
# True Label: right
# Predicted Label: left
# ---
# Sample: Pues para no entender nada de economía, bien que se forran todos en cuanto tocan poder. De la de un país, no sé, pero de la suya propia son unos auténticos tiburones financieros.
# True Label: right
# Predicted Label: left
# ---
# Sample: En lo que respecta a los históricos y a los críticos del [POLITICAL_PARTY], lo único que sería creíble a estas alturas es que abandonaran en masa el partido y crearan un partido alternativo, de izquierda no antiespañola. Todo lo demás son brindis al sol.
# True Label: left
# Predicted Label: right
# ---
# Sample: Retuitear esto de Dª Lucía no sería necesario en un mundo no gobernado por perturbados y jetas anticientíficos. Pero hemos vuelto a las cavernas, con su brujo de la tribu, sus remedios milagrosos, sus explicaciones míticas y su culto animista de la pachamama.
# True Label: left
# Predicted Label: right
# ---
# Sample: @user ¿En qué parte del hilo digo eso? De hecho, en el hilo no digo nada de prohibir el aborto. ¿Está Vd. seguro de estar contestando al hilo correcto?
# True Label: right
# Predicted Label: left
# ---
# Sample: 13) Pero en muchas otras ocasiones, esa proteína "fake" sí tiene efectos dañinos, y entonces es como si la fábrica hubiera empezado a inundar el mercado de productos tóxicos.
# True Label: left
# Predicted Label: right
# ---
# Sample: Ya van más de 12.000 detenidos en las protestas en Irán.
# True Label: right
# Predicted Label: left
# ---
# Sample: Como siempre, don @user poniendo los puntos sobre las íes
# True Label: right
# Predicted Label: left
# ---
# Sample: qué manía con el ego, el paternalismo y la condescendencia. Me pongo como una fiera con este mansplaining al que se aferran tantos sin un ápice de autocrítica.... En una situación así, ¿qué haces: pasar de largo, sacar las uñas y/o contraatacar?
# True Label: left
# Predicted Label: right
# ---
# Sample: @user Gracias a vos por ayudarnos a aterrizar los problemas del agua en España, que no son pocos!. Te esperamos mas veces profesor!
# True Label: right
# Predicted Label: left
# ---
# Sample: si nada lo impide, a las 11 de la noche estará listo el botillo que tengo al fuego. [HASHTAG] [HASHTAG]
# True Label: right
# Predicted Label: left
# ---
# Sample: @user Estimada Khadija, me gustaría proponerte una cosa. ¿Podemos conversarla por MD?
# True Label: right
# Predicted Label: left
# ---
# Sample: @user hagan el favor de resaltar EN EXTREMO la iniciaciones de "Asientos reservados" ya que la más básica educación brilla por su ausencia. La gente cada vez es menos humana y más robótica.. HORROR
# True Label: right
# Predicted Label: left
# ---
# Sample: cada minuto de silencio de Bolsonaro cuenta e inquieta: Que asuma la derrota (Agora!). una se acuerda de las elecciones de EEUU de 2020 y de su sintonía con Trump... Se verá si coinciden también en torno al golpismo.
# True Label: left
# Predicted Label: right
# ---
# ...
# Predicted Label: right
# ---
# Sample: Os comparto la carta que he enviado hoy a toda la militancia del @user . España avanza con medidas progresistas. Hemos conseguido proteger a las familias y empresas con un vendaval en contra, imaginad lo que lograremos cuando el viento sople a favor.
# True Label: right
# Predicted Label: left
# ---
# Sample: Empezamos en Versalles un [HASHTAG] informal donde abordaremos la situación derivada de la injusta invasión de Ucrania perpetrada por Putin y sus consecuencias sociales y económicas. La defensa europea, la inflación, la energía y las importaciones son algunos de los asuntos a tratar.
# True Label: right
# Predicted Label: left
# ---
# Sample: El tercer eje que he tratado con las autonomías es la necesidad de acelerar la ejecución de los fondos en materia de renovables, eficiencia energética y rehabilitación de viviendas. Para ello, reduciremos los plazos y procedimientos de ejecución de los proyectos en esta área.
# True Label: right
# Predicted Label: left
# ---
# Sample: Productivo encuentro con el presidente serbio, @user  con quien he abordado varios temas de actualidad. España y Serbia seguimos trabajando para profundizar nuestras relaciones bilaterales en el ámbito político y también en otras áreas como la cultura, la defensa o el comercio.
# True Label: right
# Predicted Label: left
# ---
# Sample: Seguimos con inquietud y preocupación las tareas de búsqueda y rescate de la tripulación del barco gallego hundido en aguas de Terranova. Todo mi cariño para sus familias. El Gobierno permanece en contacto continuo con los servicios de salvamento.
# True Label: right
# Predicted Label: left
# ---
# Sample: Apostamos por la concordia y la convivencia en un futuro lleno de esperanza. Os comparto mi entrevista hoy en @user :
# True Label: right
# Predicted Label: left
# ---
# Sample: Contamos con un nuevo logro de país: más del 80% de personas mayores de 50 años tienen ya su dosis de recuerdo de la . La ciudadanía ha considerado la vacuna como un derecho, el derecho a proteger su salud, y también como un deber, el de proteger la salud de todos.
# True Label: right
# Predicted Label: left
# ---
# Sample: Nos encaminamos a un tiempo de crecimiento y oportunidades. Y España tiene mucho que ofrecer. Gracias a la estrategia económica, a los fondos europeos y a las profundas reformas que hemos emprendido, nuestro país es hoy un destino consolidado de inversión.
# True Label: right
# Predicted Label: left
# ---
# Sample: Gobernamos para la mayoría social de este país. Otros sirven a una minoría absoluta, el 0,2% de la población, cuando votan en contra de los impuestos a las grandes fortunas y entidades financieras y energéticas.
# True Label: right
# Predicted Label: left
# ---
# Sample: Nadie dijo que fuera a ser fácil.. ¡A por el siguiente!.
# True Label: right
# Predicted Label: left
# ---
# Sample: Hoy los vecinos y vecinas de Don Benito y Villanueva de la Serena deciden su futuro. La votación a la que están convocados responde a una demanda social histórica y su unión les convertiría en uno de los principales polos de desarrollo económico de Extremadura. Sumar para avanzar
# True Label: left
# Predicted Label: right
# ---
# Sample: ¡Felicidades, Carlitos!. Ya eres el número 1 más joven de la historia del tenis y acabas de ganar tu primer Gran Slam. Impresionante tu juego, @user  en estas dos semanas.
# True Label: right
# Predicted Label: left
# ---
# Sample: Yo soy responsable siempre. Y cuando hay problemas me aplico en solucionarlos.. El [POLITICAL_PARTY] se dedica a tirar la piedra y esconder la mano.
# True Label: left
# Predicted Label: right
# ---
# Sample: Ante desafíos globales: cooperación internacional y multilateralismo. Comenzamos esta cumbre del [HASHTAG] con el objetivo de avanzar en soluciones negociadas ante la crisis provocada por una guerra injusta y sentar las bases de un futuro más sostenible, justo e inclusivo.
# True Label: left
# Predicted Label: right
# ---
# Sample: Solo con repuestas europeas, concretas, factibles e inmediatas, podremos resolver el problema del alza del precio de la energía. Es un asunto común y debemos abordarlo unidos los 27 Estados de la UE. Es urgente. Vivimos una situación de emergencia y no podemos posponerlo más.
# True Label: left
# Predicted Label: right
# ---
# Sample: ¿Cuántas veces se ha roto España desde que gobernamos?. Aquí estamos: con la inflación más baja de la eurozona y la mejor tasa de empleo de los últimos 15 años. Cumplimos la Constitución todos los días y solo hay un partido que no lo hace: el [POLITICAL_PARTY].
# True Label: right
# Predicted Label: left
# ---
# Sample: La respuesta a esta crisis se conjuga con tres verbos: reformar, proteger y repartir.. Reformar nuestro modelo energético, proteger a las familias y a las empresas y repartir las cargas para que arrimen el hombro quienes pueden hacerlo y no paguen los de siempre.
# True Label: right
# Predicted Label: left
# ---
# Sample: Convertir la vivienda en el quinto pilar de Estado del Bienestar. Es el objetivo de la [HASHTAG] que aprobamos hoy, la primera en democracia. Queremos garantizar el acceso para todos/as y promover mayor transparencia en el sector. Seguimos dignificando la vida de la gente.
# True Label: right
# Predicted Label: left
# ---
# Sample: Es posible tener pensiones dignas, garantizar el mantenimiento del poder adquisitivo y asegurar la sostenibilidad del sistema. Vincular la subida de las pensiones con un supuesto afán electoralista: es una afirmación insultante para los pensionistas y denota clasismo y soberbia.
# True Label: right
# Predicted Label: left
# ---
# Sample: Somos un Gobierno que cree en el diálogo. También ahora para afrontar los efectos en España de la guerra en Ucrania. Actuaremos para protegernos impulsando un gran pacto de rentas. Esta y otras medidas formarán parte del Plan Nacional de Respuesta a la Guerra en el que trabajamos
# True Label: right
# Predicted Label: left
# ---
# Sample: @user Por si hubiera alguna duda me refiero al de Malinche Cano
# True Label: left
# Predicted Label: right
# ---
# Sample: @user Exacto. Ese es el rasgo más perverso del personaje: que es consciente de sus mentiras. Él tiene acceso a la información y a los estudios que desmontan su farsa. Pero claro, dile tú que deje de instrumentalizar todo drama en beneficio propio...
# True Label: left
# Predicted Label: right
# ---
# Sample: @user Pues el que le ha salido a él del rasca, sin ir más lejos.
# True Label: right
# Predicted Label: left
# ---
# Sample: Ay, dios, qué vergüenza más grande me ha dado esto. Prefería holocausto zombie a la invasión de los activistas emotivos.
# True Label: right
# Predicted Label: left
# ---
# Sample: @user Debe ser comodísimo y reconfortante ver la vida de manera tan simple, como una jodida polaroid pegada en la pared, plana y bidimensional: malos y buenos. Sin más arista ni matiz. Y uno mismo siempre, por supuesto, en el lado de los buenos.
# True Label: left
# Predicted Label: right
# ---
# Sample: @user Yo no quiero parecer alarmista, pero a mí me parece muy grave...
# True Label: right
# Predicted Label: left
# ---
# Sample: @user jajajajajajajaja ¡¡La vi por su culpa!! ¡¡No se lo perdonaré jamás!! ¡¡JAMÁS!!
# True Label: left
# Predicted Label: right
# ---
# Sample: @user Nos habló con mucho cariño de ti, David. En estas ocasiones, como contigo, dan ganas de tener todo el espacio del mundo en el papel porque te quedas siempre con la sensación de haber disfrutado de algo tú solo que molaría compartir con todo el mundo...
# True Label: left
# Predicted Label: right
# ---
# Sample: @user No me contestan, pero mi última aportación en un hilo es esta. Quizá no me quede demasiado tiempo ahí, amiga
# True Label: left
# Predicted Label: right
# ---
# Sample: @user Siguiendo su lógica deductiva, las películas de miedo nos enseñan que, si vienen mal dadas en una cabaña aislada, las rubias y los negros mueren los primeros, da igual cuanto corran.
# True Label: right
# Predicted Label: left
# ---
# Sample: @user Porque esto era una chorrada y por eso se podían hacer chistes en redes
# True Label: right
# Predicted Label: left
# ---
# Sample: @user ¡¡Pero son para cosas diferentes, muy señor mío!!
# True Label: right
# Predicted Label: left
# ---
# Sample: @user Claro, es el detentebala de la neolengua: se autodenominan antifascistas y, por lo tanto, lo son y ya todos los demás son los fascistas. Aunque sus actitudes sean eminentemente fascistas. Se quedan con el epígrafe pero lo vacían de significado.
# True Label: right
# Predicted Label: left
# ---
# Sample: @user De darse, serían conductas tan marginalísimas que no sería ni honesto ni veraz utilizarlas como paradigma de nada.
# True Label: left
# Predicted Label: right
# ---
# Sample: @user Yo les sugeriría, por ir concretando sin ambages, un mucho más contundente y pegadizo "fuera todos menos nosotros". De nada.
# True Label: right
# Predicted Label: left
# ---
# Sample: @user ¿No llevar dinero para que no te roben no sería el equivalente a no llevar minifalda para que no te violen? Admiro de los progresistas su capacidad para elevar a dogma indiscutible lo que en el de enfrente es prueba irrefutable de maldad.
# True Label: right
# Predicted Label: left
# ---
# Sample: @user No me sorprende. Ya se negó hace años a reunirse con activistas feministas de origen musulmán mientras sí lo hacía con mujeres hiyabis...
# True Label: right
# Predicted Label: left
# ---
# Sample: En esto (bueno, y en más cosas, pero por no entretener), a tope con @user : si dice "cuñado" no telofo.
# True Label: right
# Predicted Label: left
# ---
# Sample: @user Mándenos por la mañana una lista de todo sobre lo que tenemos que opinar para que no le dé el parraque y así que no se nos pase nada, oiga. Que no nos da la vida para tenerlo contento.
# True Label: right
# Predicted Label: left
# ---
# Sample: @user Como diría Gila: alguien le guiña el ojo a alguien...
# True Label: left
# Predicted Label: right
# ---
# Sample: @user A mí me habría jodido más el uso del pretérito imperfecto de indicativo delante de "un joven" que lo que trata de insinuar, Cristian. ¡¡Sigues siendo un joven periodista, hostias!!
# True Label: right
# Predicted Label: left
# ---
# Sample: A algunos se les olvida que la obligación de la prensa es fiscalizar a los poderes y creen que los medios están a su servicio. Enhorabuena a ABC y a @user por hacer periodismo y no propaganda.
# True Label: right
# Predicted Label: left
# ---
# Sample: @user Pero sobre lo que se sustentan sus cursos y su sueldo. Como para esperar honestidad y que rectifique...
# True Label: right
# Predicted Label: left
# ---
# Sample: A mí porque nunca me hacéis caso pero para drama por relaciones que se acaban el del Director del Reina Sofía, primos, y no el de Shakira:.
# True Label: right
# Predicted Label: left
# ---
# Sample: @user Estoy esperando viñeta, querido. Que lo sepas. Quiero viñeta aunque solo sea boceto y para estos ojitos.
# True Label: right
# Predicted Label: left
# ---
# Sample: Estimada @user dos puntos. ¿Cómo se come que OS adhiráis al programa stop rumores al tiempo que mantenéis a Miguel Lorente con puesto en mando después de publicar artículos con datos manipulados? Pregunto...
# True Label: left
# Predicted Label: right
# ---
# Sample: - [POLITICIAN]: "A que nadie supera lo de 'mi primo me ha dicho que el cambio climático no existe?'". - [POLITICAL_PARTY] en la asamblea de Murcia: "sujétame el cubata".
# True Label: right
# Predicted Label: left
# ---
# Sample: Reto en vivienda. El [POLITICAL_PARTY] manda un mensaje distinto al que mandan los Presupuestos. Vemos con tristeza como se pasa una oportunidad para mejorar la Vivienda como se ha hecho con sanidad o IMV. El [POLITICAL_PARTY] debe trabajar para la ciudadanía, no para los fondos buitres.
# True Label: right
# Predicted Label: left
# ---
# Sample: 3. Hemos alcanzado por primera vez en la historia los 20 millones de afiliados. La subida también coincide con la Reforma Laboral.
# True Label: right
# Predicted Label: left
# ---
# Sample: Lo que empezó a gestar el movimiento feminista se aprueba hoy definitivamente en el Congreso con una mayoría amplia. Enhorabuena a todas por la lucha. Enhorabuena @user y @user .
# True Label: right
# Predicted Label: left
# ---
# Sample: A los recursos del cartel hay que añadirle estos otros recursos:. 👉La modificación de las penas de prisión para piquetes sindicales. 👉El IMV. 👉Normas sobre igualdad. 👉El régimen jurídico aplicable al CGPJ en funciones. (3/6)
# True Label: right
# Predicted Label: left
# ---
# Sample: 5 niños muertos tras un bombardeo israelí no son “un polémico incidente con un cohete”. 37 migrantes muertos en Melilla no son “una operación bien resuelta”.. Son crímenes atroces que ofenden a toda la humanidad.
# True Label: right
# Predicted Label: left
# ---
# Sample: Es una reliquia del pasado llena de polvo de un mundo que ya no existe:. (2/7)
# True Label: left
# Predicted Label: right
# ---
# Sample: Nuestras peticiones para la Ley de Vivienda:. 1. Limitar precios de alquiler. 2. Prohibir desahucios sin alternativa habitacional. 3. Ampliar el parque de vivienda pública (con la SAREB). Si se ha hecho en Europa, se debe poder hacer aquí.
# True Label: right
# Predicted Label: left
# ---
# Sample: La masacre de Melilla fue una vergüenza e Interior incumplió la ley. Lo dijo hasta la ONU o el Defensor del Pueblo. Hoy, también la BBC. Marlaska debe rectificar y el [POLITICAL_PARTY] dejar de bloquear, con [POLITICAL_PARTY] y [POLITICAL_PARTY], la investigación del Congreso. Exigimos verdad, justicia y reparación.
# True Label: right
# Predicted Label: left
# ---
# Sample: Algunos llevan teniendo "problemas de agenda" cuatro años. Que dejen de engañar a la ciudadanía y cumplan la ley.
# True Label: right
# Predicted Label: left
# ---
# Sample: Moción de censura a [POLITICIAN]: +12M votos. PGE del 2021: +12M votos. PGE del 2022: +12M votos. PGE del 2023: +12M votos. Derogación del delito de sedición: 11,5M votos.. [POLITICAL_PARTY] y [POLITICAL_PARTY]: 8,5M.. ¿Quién es la minoría y quién la mayoría?.
# True Label: right
# Predicted Label: left
# ---
# Sample: 👉🏾 La media de edad de las personas que comparten piso pasó en cinco años de los 29 a 34. La media de emancipación está en los 30 años. 👉🏾 En países cono Alemania, Francia o Dinamarca se ha regulado el precio del alquiler y la edad media de emancipación baja de los 24. (4/7)
# True Label: right
# Predicted Label: left
# ---
# Sample: Pedir casi 10 años de cárcel a un abogado por quienes son sus clientes es un atentado grave al Estado de Derecho. Y al conjunto de la abogacía. No nos cansaremos de repetirlo. Toda la solidaridad, @user
# True Label: right
# Predicted Label: left
# ---
# Sample: Dicho esto, ‘don’t feed the troll’. Viendo los efectos del cambio climático en incendios y en el quinto día consecutivo a más de 40º, el debate debería ser cómo avanzar hacia la sostenibilidad energética o en una gestión forestal pública de calidad. (4/4).
# True Label: left
# Predicted Label: right
# ---
# Sample: Hoy vencen la política y la democracia. Derogamos un delito predemocrático. Una espada de Damocles para el derecho a protesta. Un paso necesario para la desjudicialización del conflicto en Catalunya.. Hoy acabamos con el delito de sedición.
# True Label: left
# Predicted Label: right
# ---
# Sample: Mucho orgullo y dignidad hoy en la escalinata del Congreso de los Diputados al grito de !. Recibimos las más de 700 mil firmas para impulsar una ILP que logre la plenitud de derechos de las personas migrantes.
# True Label: right
# Predicted Label: left
# ---
# Sample: ¿Saben quienes también querían que sus miembros tuvieran una pistola? Los de [POLITICAL_PARTY].
# True Label: right
# Predicted Label: left
# ---
# Sample: Hoy un periodista me ha dicho que mucha gente no entiende qué está pasando. Lo pongo claro:. 👉 En el TC hay jueces actuando al servicio del [POLITICAL_PARTY]. 👉 Su mandato ha terminado y no se quieren ir. 👉 Su objetivo: tumbar leyes ya aprobadas como la Eutanasia, el Aborto o el IMV. Hilo🧵
# True Label: left
# Predicted Label: right
# ---
# Sample: Hoy, periodistas, artistas y políticos de distintos colores firmamos una carta de apoyo a la decisión de Barcelona de suspender las relaciones con Israel. Sin acciones como ésta, el apartheid en Sudáfrica no habría terminado. (2/7).
# True Label: left
# Predicted Label: right
# ---
